# %%
import os
import sys
import pandas as pd
import numpy as np

# Set up directories
code_dir = os.path.dirname(os.getcwd())
classes_dir = os.path.join(code_dir, 'classes')
project_dir = os.path.dirname(code_dir)
data_dir = os.path.join(project_dir, 'data')

# Add classes directory to sys.path
sys.path.append(classes_dir)

# Import custom classes
from DATA import Data

# %%
data = Data(data_dir)

# %%
# Nutrients
data.N
# Out:
# ['Energy (kcal)',
#  'Protein (g)',
#  'Fat (g)',
#  'Calcium (mg)',
#  'Folic acid (µg DFE)',
#  'Iron absorbed (mg)',
#  'Iron (mg)',
#  'Magnesium (mg)',
#  'Niacin (mg NE)',
#  'Pantothenic acid (mg)',
#  'Vitamin A (μg RAE)',
#  'Vitamin B1 (mg)',
#  'Vitamin B2 (mg)',
#  'Vitamin B6 (mg)',
#  'Vitamin B12 (µg)',
#  'Vitamin C (mg)',
#  'Zinc (mg)']

# %%
# Food items
data.I
# Out:
# ['Noodles, rice, cooked',
#  'Rice, white, polished, raw',
#  'Noodles, egg, dry, enriched',
#  'Cassava, white',
#  'Plantain, all varieties',
#  'Sweet potato, purple skin, pale yellow flesh, raw',
#  'Sweet potato, white flesh, raw',
#  'Taro, tuber, raw',
#  'Yam bean, jicama, raw',
#  'Cabbage, chinese, pak choi, raw',
#  'Cabbage, chinese, pe tsai, raw',
#  'Cabbage, chinese, raw',
#  'Ivygourd, leaf, raw',
#  'Kale, raw',
#  'Leaf, amaranth, spiney, raw',
#  'Leaf, bitter gourd, raw',
#  'Leaf, drumstick, raw',
#  'Leaf, greens, mustard',
#  'Leaf, mustard spinach, raw',
#  'Leaf, pumpkin, raw',
#  'Water spinach, raw',
#  'Banana flower heart',
#  'Bean, yard long bean, immature, raw',
#  'Carrot, raw',
#  'Cauliflower, raw',
#  'Cucumber, raw',
#  'Eggplant, purple',
#  'Eggplant, raw',
#  'Gourd, bitter, raw',
#  'Gourd, ridge, raw',
#  'Gourd, sponge, raw',
#  'Gourd, wax',
#  'Mushrooms, shiitake, dried',
#  'Mushrooms, shiitake, raw',
#  'Onion, raw',
#  'Pumpkin, raw',
#  'Radish, chinese, raw',
#  'Tomato, red, ripe, raw',
#  'Banana, ripe',
#  'Guava',
#  'Jackfruit, ripe',
#  'Orange',
#  'Pineapple, ripe',
#  'Mango, ripe',
#  'Mango, unripe',
#  'Papaya, ripe',
#  'Papaya, unripe, raw',
#  'Sapote, yellow',
#  'Milk, cow, fresh',
#  'Yogurt',
#  'Egg, chicken, farmed, raw',
#  'Egg, duck, whole, raw',
#  'Fish, Snakehead, dried',
#  'Fish, tilapia, dried',
#  'Fish, barb, pool, with bones, eyes included, raw',
#  'Fish, catfish, raw',
#  'Fish, days mystus, eyes included, raw',
#  'Fish, gouramy, eyes included, raw',
#  'Fish, small, fresh, fresh water',
#  'Fish, snakehead, striped, raw',
#  'Fish, tilapia, raw',
#  'Fish paste, red, fermented',
#  'Shrimp, raw',
#  'Squid, raw',
#  'Chicken, liver, raw',
#  'Chicken, meat',
#  'Duck, liver, raw',
#  'Duck, meat, raw',
#  'Quail, meat',
#  'Beef, blood, coagulated',
#  'Beef, liver, raw',
#  'Beef, meat, lean, boneless, raw',
#  'Pork or Goat, blood, coagulated',
#  'Pork, back ribs, raw',
#  'Pork, liver, raw',
#  'Pork, meat, raw',
#  'Bean, kidney, dried, raw',
#  'Bean, mung, dry',
#  'Beansprout, mung bean, raw',
#  'Peanut, without shell',
#  'Soybean, dried, raw',
#  'Tofu',
#  'Butter, CotD',
#  'Oil, vegetable',
#  'Sugar, palm',
#  'Sugar, white']

# %%
# Nutritional values dic
data.a
# Out:
# {'Noodles, rice, cooked': {'Energy (kcal)': 108,
#   'Protein (g)': 1.79,
#   'Fat (g)': 0.2,
#   'Calcium (mg)': 4.0,
#   'Folic acid (µg DFE)': 1.0,
#   'Iron absorbed (mg)': 0.007,
#   'Iron (mg)': 0.14,
#   'Magnesium (mg)': 3.0,
#   'Niacin (mg NE)': 0.072,
#   'Pantothenic acid (mg)': 0.011,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.018,
#   'Vitamin B2 (mg)': 0.004,
#   'Vitamin B6 (mg)': 0.006,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 0.25},
#  'Rice, white, polished, raw': {'Energy (kcal)': 353,
#   'Protein (g)': 6.141215299,
#   'Fat (g)': 0.462644305,
#   'Calcium (mg)': 10.8381217,
#   'Folic acid (µg DFE)': 20.0,
#   'Iron absorbed (mg)': 0.036509675,
#   'Iron (mg)': 0.730193501,
#   'Magnesium (mg)': 35.0,
#   'Niacin (mg NE)': 0.4231056,
#   'Pantothenic acid (mg)': 1.080266304,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.072782633,
#   'Vitamin B2 (mg)': 0.027145539,
#   'Vitamin B6 (mg)': 0.125,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 1.1},
#  'Noodles, egg, dry, enriched': {'Energy (kcal)': 384,
#   'Protein (g)': 14.16,
#   'Fat (g)': 4.44,
#   'Calcium (mg)': 35.0,
#   'Folic acid (µg DFE)': 230.0,
#   'Iron absorbed (mg)': 0.2005,
#   'Iron (mg)': 4.01,
#   'Magnesium (mg)': 58.0,
#   'Niacin (mg NE)': 8.387,
#   'Pantothenic acid (mg)': 0.912,
#   'Vitamin A (μg RAE)': 17.0,
#   'Vitamin B1 (mg)': 1.133,
#   'Vitamin B2 (mg)': 0.426,
#   'Vitamin B6 (mg)': 0.216,
#   'Vitamin B12 (µg)': 0.29,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 1.92},
#  'Cassava, white': {'Energy (kcal)': 131,
#   'Protein (g)': 1.1,
#   'Fat (g)': 0.3,
#   'Calcium (mg)': 19.0,
#   'Folic acid (µg DFE)': 15.0,
#   'Iron absorbed (mg)': 0.04,
#   'Iron (mg)': 0.8,
#   'Magnesium (mg)': 10.0,
#   'Niacin (mg NE)': 0.85,
#   'Pantothenic acid (mg)': 0.29,
#   'Vitamin A (μg RAE)': 3.0,
#   'Vitamin B1 (mg)': 0.13,
#   'Vitamin B2 (mg)': 0.02,
#   'Vitamin B6 (mg)': 0.29,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 30.0,
#   'Zinc (mg)': 0.3},
#  'Plantain, all varieties': {'Energy (kcal)': 116,
#   'Protein (g)': 0.8,
#   'Fat (g)': 0.2,
#   'Calcium (mg)': 2.0,
#   'Folic acid (µg DFE)': 26.0,
#   'Iron absorbed (mg)': 0.03,
#   'Iron (mg)': 0.6,
#   'Magnesium (mg)': 32.0,
#   'Niacin (mg NE)': 0.95,
#   'Pantothenic acid (mg)': 0.23,
#   'Vitamin A (μg RAE)': 45.5,
#   'Vitamin B1 (mg)': 0.05,
#   'Vitamin B2 (mg)': 0.05,
#   'Vitamin B6 (mg)': 0.24,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 11.0,
#   'Zinc (mg)': 0.1},
#  'Sweet potato, purple skin, pale yellow flesh, raw': {'Energy (kcal)': 104,
#   'Protein (g)': 0.635,
#   'Fat (g)': 0.26,
#   'Calcium (mg)': 32.0,
#   'Folic acid (µg DFE)': 11.0,
#   'Iron absorbed (mg)': 0.072045,
#   'Iron (mg)': 1.4409,
#   'Magnesium (mg)': 27.0,
#   'Niacin (mg NE)': 0.8,
#   'Pantothenic acid (mg)': 0.370597953,
#   'Vitamin A (μg RAE)': 3.25,
#   'Vitamin B1 (mg)': 0.078,
#   'Vitamin B2 (mg)': 0.061,
#   'Vitamin B6 (mg)': 0.209,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 35.1475,
#   'Zinc (mg)': 0.400275},
#  'Sweet potato, white flesh, raw': {'Energy (kcal)': 98,
#   'Protein (g)': 0.615,
#   'Fat (g)': 0.26,
#   'Calcium (mg)': 24.5,
#   'Folic acid (µg DFE)': 11.0,
#   'Iron absorbed (mg)': 0.07575,
#   'Iron (mg)': 1.515,
#   'Magnesium (mg)': 25.0,
#   'Niacin (mg NE)': 0.8,
#   'Pantothenic acid (mg)': 0.370597953,
#   'Vitamin A (μg RAE)': 1.416666667,
#   'Vitamin B1 (mg)': 0.078,
#   'Vitamin B2 (mg)': 0.061,
#   'Vitamin B6 (mg)': 0.209,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 20.266,
#   'Zinc (mg)': 0.383066667},
#  'Taro, tuber, raw': {'Energy (kcal)': 92,
#   'Protein (g)': 1.701387963,
#   'Fat (g)': 0.1,
#   'Calcium (mg)': 33.3213,
#   'Folic acid (µg DFE)': 22.0,
#   'Iron absorbed (mg)': 0.045,
#   'Iron (mg)': 0.9,
#   'Magnesium (mg)': 22.01875926,
#   'Niacin (mg NE)': 0.8,
#   'Pantothenic acid (mg)': 0.370597953,
#   'Vitamin A (μg RAE)': 1.875,
#   'Vitamin B1 (mg)': 0.1,
#   'Vitamin B2 (mg)': 0.03,
#   'Vitamin B6 (mg)': 0.24,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 8.0,
#   'Zinc (mg)': 0.4176},
#  'Yam bean, jicama, raw': {'Energy (kcal)': 38,
#   'Protein (g)': 0.72,
#   'Fat (g)': 0.09,
#   'Calcium (mg)': 12.0,
#   'Folic acid (µg DFE)': 12.0,
#   'Iron absorbed (mg)': 0.03,
#   'Iron (mg)': 0.6,
#   'Magnesium (mg)': 12.0,
#   'Niacin (mg NE)': 0.2,
#   'Pantothenic acid (mg)': 0.135,
#   'Vitamin A (μg RAE)': 1.0,
#   'Vitamin B1 (mg)': 0.02,
#   'Vitamin B2 (mg)': 0.029,
#   'Vitamin B6 (mg)': 0.042,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 20.2,
#   'Zinc (mg)': 0.16},
#  'Cabbage, chinese, pak choi, raw': {'Energy (kcal)': 13,
#   'Protein (g)': 1.5,
#   'Fat (g)': 0.2,
#   'Calcium (mg)': 105.0,
#   'Folic acid (µg DFE)': 66.0,
#   'Iron absorbed (mg)': 0.04,
#   'Iron (mg)': 0.8,
#   'Magnesium (mg)': 19.0,
#   'Niacin (mg NE)': 0.5,
#   'Pantothenic acid (mg)': 0.088,
#   'Vitamin A (μg RAE)': 223.0,
#   'Vitamin B1 (mg)': 0.04,
#   'Vitamin B2 (mg)': 0.07,
#   'Vitamin B6 (mg)': 0.194,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 45.0,
#   'Zinc (mg)': 0.19},
#  'Cabbage, chinese, pe tsai, raw': {'Energy (kcal)': 16,
#   'Protein (g)': 1.2,
#   'Fat (g)': 0.2,
#   'Calcium (mg)': 77.0,
#   'Folic acid (µg DFE)': 79.0,
#   'Iron absorbed (mg)': 0.0155,
#   'Iron (mg)': 0.31,
#   'Magnesium (mg)': 13.0,
#   'Niacin (mg NE)': 0.4,
#   'Pantothenic acid (mg)': 0.105,
#   'Vitamin A (μg RAE)': 16.0,
#   'Vitamin B1 (mg)': 0.04,
#   'Vitamin B2 (mg)': 0.05,
#   'Vitamin B6 (mg)': 0.232,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 27.0,
#   'Zinc (mg)': 0.23},
#  'Cabbage, chinese, raw': {'Energy (kcal)': 15,
#   'Protein (g)': 2.3,
#   'Fat (g)': 0.2,
#   'Calcium (mg)': 74.0,
#   'Folic acid (µg DFE)': 73.0,
#   'Iron absorbed (mg)': 0.055,
#   'Iron (mg)': 1.1,
#   'Magnesium (mg)': 15.0,
#   'Niacin (mg NE)': 0.816666667,
#   'Pantothenic acid (mg)': 0.02,
#   'Vitamin A (μg RAE)': 151.5,
#   'Vitamin B1 (mg)': 0.04,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.11,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 25.0,
#   'Zinc (mg)': 0.2},
#  'Ivygourd, leaf, raw': {'Energy (kcal)': 37,
#   'Protein (g)': 3.6,
#   'Fat (g)': 0.2,
#   'Calcium (mg)': 57.0,
#   'Folic acid (µg DFE)': 36.0,
#   'Iron absorbed (mg)': 0.07,
#   'Iron (mg)': 1.4,
#   'Magnesium (mg)': 68.695,
#   'Niacin (mg NE)': 19.0,
#   'Pantothenic acid (mg)': 0.16225,
#   'Vitamin A (μg RAE)': 336.0,
#   'Vitamin B1 (mg)': 0.11,
#   'Vitamin B2 (mg)': 0.17,
#   'Vitamin B6 (mg)': 0.21,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 13.0,
#   'Zinc (mg)': 0.5},
#  'Kale, raw': {'Energy (kcal)': 49,
#   'Protein (g)': 4.28,
#   'Fat (g)': 0.93,
#   'Calcium (mg)': 150.0,
#   'Folic acid (µg DFE)': 141.0,
#   'Iron absorbed (mg)': 0.0735,
#   'Iron (mg)': 1.47,
#   'Magnesium (mg)': 47.0,
#   'Niacin (mg NE)': 1.0,
#   'Pantothenic acid (mg)': 0.091,
#   'Vitamin A (μg RAE)': 500.0,
#   'Vitamin B1 (mg)': 0.11,
#   'Vitamin B2 (mg)': 0.13,
#   'Vitamin B6 (mg)': 0.271,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 120.0,
#   'Zinc (mg)': 0.56},
#  'Leaf, amaranth, spiney, raw': {'Energy (kcal)': 51,
#   'Protein (g)': 4.8033,
#   'Fat (g)': 0.25,
#   'Calcium (mg)': 639.5,
#   'Folic acid (µg DFE)': 85.0,
#   'Iron absorbed (mg)': 0.0,
#   'Iron (mg)': 0.0,
#   'Magnesium (mg)': 0.0,
#   'Niacin (mg NE)': 1.6,
#   'Pantothenic acid (mg)': 0.162249625,
#   'Vitamin A (μg RAE)': 908.0,
#   'Vitamin B1 (mg)': 0.03,
#   'Vitamin B2 (mg)': 0.055,
#   'Vitamin B6 (mg)': 0.192,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 43.36666667,
#   'Zinc (mg)': 0.32},
#  'Leaf, bitter gourd, raw': {'Energy (kcal)': 30,
#   'Protein (g)': 5.3,
#   'Fat (g)': 0.69,
#   'Calcium (mg)': 84.0,
#   'Folic acid (µg DFE)': 128.0,
#   'Iron absorbed (mg)': 0.102,
#   'Iron (mg)': 2.04,
#   'Magnesium (mg)': 85.0,
#   'Niacin (mg NE)': 1.11,
#   'Pantothenic acid (mg)': 0.063,
#   'Vitamin A (μg RAE)': 87.0,
#   'Vitamin B1 (mg)': 0.181,
#   'Vitamin B2 (mg)': 0.362,
#   'Vitamin B6 (mg)': 0.803,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 88.0,
#   'Zinc (mg)': 0.3},
#  'Leaf, drumstick, raw': {'Energy (kcal)': 72,
#   'Protein (g)': 6.7,
#   'Fat (g)': 1.799533333,
#   'Calcium (mg)': 440.0,
#   'Folic acid (µg DFE)': 205.0,
#   'Iron absorbed (mg)': 0.0425,
#   'Iron (mg)': 0.85,
#   'Magnesium (mg)': 42.0,
#   'Niacin (mg NE)': 2.6,
#   'Pantothenic acid (mg)': 0.162249625,
#   'Vitamin A (μg RAE)': 1100.0,
#   'Vitamin B1 (mg)': 0.257,
#   'Vitamin B2 (mg)': 0.66,
#   'Vitamin B6 (mg)': 1.2,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 220.0,
#   'Zinc (mg)': 0.16},
#  'Leaf, greens, mustard': {'Energy (kcal)': 15,
#   'Protein (g)': 2.3,
#   'Fat (g)': 0.2,
#   'Calcium (mg)': 74.0,
#   'Folic acid (µg DFE)': 73.0,
#   'Iron absorbed (mg)': 0.055,
#   'Iron (mg)': 1.1,
#   'Magnesium (mg)': 15.0,
#   'Niacin (mg NE)': 0.816666667,
#   'Pantothenic acid (mg)': 0.02,
#   'Vitamin A (μg RAE)': 151.5,
#   'Vitamin B1 (mg)': 0.04,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.11,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 25.0,
#   'Zinc (mg)': 0.2},
#  'Leaf, mustard spinach, raw': {'Energy (kcal)': 22,
#   'Protein (g)': 2.2,
#   'Fat (g)': 0.3,
#   'Calcium (mg)': 210.0,
#   'Folic acid (µg DFE)': 159.0,
#   'Iron absorbed (mg)': 0.075,
#   'Iron (mg)': 1.5,
#   'Magnesium (mg)': 11.0,
#   'Niacin (mg NE)': 0.678,
#   'Pantothenic acid (mg)': 0.178,
#   'Vitamin A (μg RAE)': 495.0,
#   'Vitamin B1 (mg)': 0.068,
#   'Vitamin B2 (mg)': 0.093,
#   'Vitamin B6 (mg)': 0.153,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 130.0,
#   'Zinc (mg)': 0.17},
#  'Leaf, pumpkin, raw': {'Energy (kcal)': 29,
#   'Protein (g)': 2.442,
#   'Fat (g)': 0.44,
#   'Calcium (mg)': 40.0,
#   'Folic acid (µg DFE)': 36.0,
#   'Iron absorbed (mg)': 0.111,
#   'Iron (mg)': 2.22,
#   'Magnesium (mg)': 38.0,
#   'Niacin (mg NE)': 1.453333333,
#   'Pantothenic acid (mg)': 0.162249625,
#   'Vitamin A (μg RAE)': 161.6666667,
#   'Vitamin B1 (mg)': 0.12,
#   'Vitamin B2 (mg)': 0.24,
#   'Vitamin B6 (mg)': 0.207,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 37.2,
#   'Zinc (mg)': 0.2},
#  'Water spinach, raw': {'Energy (kcal)': 43,
#   'Protein (g)': 1.921666667,
#   'Fat (g)': 0.384,
#   'Calcium (mg)': 107.0,
#   'Folic acid (µg DFE)': 57.0,
#   'Iron absorbed (mg)': 0.109879833,
#   'Iron (mg)': 2.197596667,
#   'Magnesium (mg)': 19.42,
#   'Niacin (mg NE)': 0.9,
#   'Pantothenic acid (mg)': 0.162249625,
#   'Vitamin A (μg RAE)': 198.64,
#   'Vitamin B1 (mg)': 0.14,
#   'Vitamin B2 (mg)': 0.4,
#   'Vitamin B6 (mg)': 0.096,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 30.3925,
#   'Zinc (mg)': 0.51053},
#  'Banana flower heart': {'Energy (kcal)': 21,
#   'Protein (g)': 1.2,
#   'Fat (g)': 0.7,
#   'Calcium (mg)': 20.0,
#   'Folic acid (µg DFE)': 40.0,
#   'Iron absorbed (mg)': 0.035,
#   'Iron (mg)': 0.7,
#   'Magnesium (mg)': 2.0,
#   'Niacin (mg NE)': 0.55,
#   'Pantothenic acid (mg)': 0.1,
#   'Vitamin A (μg RAE)': 48.0,
#   'Vitamin B1 (mg)': 0.02,
#   'Vitamin B2 (mg)': 0.02,
#   'Vitamin B6 (mg)': 0.05,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 7.0,
#   'Zinc (mg)': 0.2},
#  'Bean, yard long bean, immature, raw': {'Energy (kcal)': 47,
#   'Protein (g)': 2.8,
#   'Fat (g)': 0.4,
#   'Calcium (mg)': 50.0,
#   'Folic acid (µg DFE)': 62.0,
#   'Iron absorbed (mg)': 0.0235,
#   'Iron (mg)': 0.47,
#   'Magnesium (mg)': 44.0,
#   'Niacin (mg NE)': 0.41,
#   'Pantothenic acid (mg)': 0.055,
#   'Vitamin A (μg RAE)': 43.0,
#   'Vitamin B1 (mg)': 0.107,
#   'Vitamin B2 (mg)': 0.11,
#   'Vitamin B6 (mg)': 0.024,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 18.8,
#   'Zinc (mg)': 0.37},
#  'Carrot, raw': {'Energy (kcal)': 45,
#   'Protein (g)': 1.1,
#   'Fat (g)': 0.2,
#   'Calcium (mg)': 31.0,
#   'Folic acid (µg DFE)': 14.0,
#   'Iron absorbed (mg)': 0.03,
#   'Iron (mg)': 0.6,
#   'Magnesium (mg)': 13.0,
#   'Niacin (mg NE)': 0.7,
#   'Pantothenic acid (mg)': 0.3,
#   'Vitamin A (μg RAE)': 971.0,
#   'Vitamin B1 (mg)': 0.03,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.25,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 2.0,
#   'Zinc (mg)': 0.3},
#  'Cauliflower, raw': {'Energy (kcal)': 25,
#   'Protein (g)': 1.4,
#   'Fat (g)': 0.3,
#   'Calcium (mg)': 47.0,
#   'Folic acid (µg DFE)': 43.0,
#   'Iron absorbed (mg)': 0.03,
#   'Iron (mg)': 0.6,
#   'Magnesium (mg)': 15.0,
#   'Niacin (mg NE)': 0.55,
#   'Pantothenic acid (mg)': 0.14,
#   'Vitamin A (μg RAE)': 6.5,
#   'Vitamin B1 (mg)': 0.05,
#   'Vitamin B2 (mg)': 0.04,
#   'Vitamin B6 (mg)': 0.1,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 32.0,
#   'Zinc (mg)': 0.2},
#  'Cucumber, raw': {'Energy (kcal)': 13,
#   'Protein (g)': 0.7,
#   'Fat (g)': 0.1,
#   'Calcium (mg)': 14.0,
#   'Folic acid (µg DFE)': 13.0,
#   'Iron absorbed (mg)': 0.015,
#   'Iron (mg)': 0.3,
#   'Magnesium (mg)': 11.0,
#   'Niacin (mg NE)': 0.283333333,
#   'Pantothenic acid (mg)': 0.18,
#   'Vitamin A (μg RAE)': 10.5,
#   'Vitamin B1 (mg)': 0.02,
#   'Vitamin B2 (mg)': 0.02,
#   'Vitamin B6 (mg)': 0.04,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 5.0,
#   'Zinc (mg)': 0.2},
#  'Eggplant, purple': {'Energy (kcal)': 28,
#   'Protein (g)': 0.8,
#   'Fat (g)': 0.2,
#   'Calcium (mg)': 6.0,
#   'Folic acid (µg DFE)': 14.0,
#   'Iron absorbed (mg)': 0.02,
#   'Iron (mg)': 0.4,
#   'Magnesium (mg)': 13.0,
#   'Niacin (mg NE)': 0.733333333,
#   'Pantothenic acid (mg)': 0.08,
#   'Vitamin A (μg RAE)': 3.0,
#   'Vitamin B1 (mg)': 0.08,
#   'Vitamin B2 (mg)': 0.02,
#   'Vitamin B6 (mg)': 0.09,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 1.0,
#   'Zinc (mg)': 0.2},
#  'Eggplant, raw': {'Energy (kcal)': 25,
#   'Protein (g)': 0.98,
#   'Fat (g)': 0.18,
#   'Calcium (mg)': 9.0,
#   'Folic acid (µg DFE)': 22.0,
#   'Iron absorbed (mg)': 0.0115,
#   'Iron (mg)': 0.23,
#   'Magnesium (mg)': 14.0,
#   'Niacin (mg NE)': 0.649,
#   'Pantothenic acid (mg)': 0.281,
#   'Vitamin A (μg RAE)': 1.0,
#   'Vitamin B1 (mg)': 0.039,
#   'Vitamin B2 (mg)': 0.037,
#   'Vitamin B6 (mg)': 0.084,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 2.2,
#   'Zinc (mg)': 0.16},
#  'Gourd, bitter, raw': {'Energy (kcal)': 31,
#   'Protein (g)': 2.055,
#   'Fat (g)': 0.3425,
#   'Calcium (mg)': 15.982,
#   'Folic acid (µg DFE)': 45.0,
#   'Iron absorbed (mg)': 0.0892125,
#   'Iron (mg)': 1.78425,
#   'Magnesium (mg)': 31.25,
#   'Niacin (mg NE)': 0.7,
#   'Pantothenic acid (mg)': 0.445144547,
#   'Vitamin A (μg RAE)': 23.78888889,
#   'Vitamin B1 (mg)': 0.05,
#   'Vitamin B2 (mg)': 0.033333333,
#   'Vitamin B6 (mg)': 0.0,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 90.63166667,
#   'Zinc (mg)': 0.3473},
#  'Gourd, ridge, raw': {'Energy (kcal)': 29,
#   'Protein (g)': 1.275,
#   'Fat (g)': 0.35,
#   'Calcium (mg)': 20.73333333,
#   'Folic acid (µg DFE)': 7.0,
#   'Iron absorbed (mg)': 0.062916667,
#   'Iron (mg)': 1.258333333,
#   'Magnesium (mg)': 14.0,
#   'Niacin (mg NE)': 0.5,
#   'Pantothenic acid (mg)': 0.445144547,
#   'Vitamin A (μg RAE)': 2.166666667,
#   'Vitamin B1 (mg)': 0.11,
#   'Vitamin B2 (mg)': 0.03,
#   'Vitamin B6 (mg)': 0.043,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 4.5925,
#   'Zinc (mg)': 0.50095},
#  'Gourd, sponge, raw': {'Energy (kcal)': 24,
#   'Protein (g)': 0.89,
#   'Fat (g)': 0.15,
#   'Calcium (mg)': 19.15,
#   'Folic acid (µg DFE)': 7.0,
#   'Iron absorbed (mg)': 0.03,
#   'Iron (mg)': 0.6,
#   'Magnesium (mg)': 14.0,
#   'Niacin (mg NE)': 0.2,
#   'Pantothenic acid (mg)': 0.445144547,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.03,
#   'Vitamin B2 (mg)': 0.01,
#   'Vitamin B6 (mg)': 0.043,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 6.2,
#   'Zinc (mg)': 0.5},
#  'Gourd, wax': {'Energy (kcal)': 20,
#   'Protein (g)': 0.9,
#   'Fat (g)': 0.3,
#   'Calcium (mg)': 27.0,
#   'Folic acid (µg DFE)': 20.0,
#   'Iron absorbed (mg)': 0.02,
#   'Iron (mg)': 0.4,
#   'Magnesium (mg)': 24.0,
#   'Niacin (mg NE)': 0.633333333,
#   'Pantothenic acid (mg)': 0.14,
#   'Vitamin A (μg RAE)': 14.5,
#   'Vitamin B1 (mg)': 0.04,
#   'Vitamin B2 (mg)': 0.04,
#   'Vitamin B6 (mg)': 0.07,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 6.0,
#   'Zinc (mg)': 0.4},
#  'Mushrooms, shiitake, dried': {'Energy (kcal)': 296,
#   'Protein (g)': 9.58,
#   'Fat (g)': 0.99,
#   'Calcium (mg)': 11.0,
#   'Folic acid (µg DFE)': 163.0,
#   'Iron absorbed (mg)': 0.086,
#   'Iron (mg)': 1.72,
#   'Magnesium (mg)': 132.0,
#   'Niacin (mg NE)': 14.1,
#   'Pantothenic acid (mg)': 21.879,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.3,
#   'Vitamin B2 (mg)': 1.27,
#   'Vitamin B6 (mg)': 0.965,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 3.5,
#   'Zinc (mg)': 7.66},
#  'Mushrooms, shiitake, raw': {'Energy (kcal)': 34,
#   'Protein (g)': 2.24,
#   'Fat (g)': 0.49,
#   'Calcium (mg)': 2.0,
#   'Folic acid (µg DFE)': 13.0,
#   'Iron absorbed (mg)': 0.0205,
#   'Iron (mg)': 0.41,
#   'Magnesium (mg)': 20.0,
#   'Niacin (mg NE)': 3.877,
#   'Pantothenic acid (mg)': 1.5,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.015,
#   'Vitamin B2 (mg)': 0.217,
#   'Vitamin B6 (mg)': 0.293,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 1.03},
#  'Onion, raw': {'Energy (kcal)': 59,
#   'Protein (g)': 1.375,
#   'Fat (g)': 0.074,
#   'Calcium (mg)': 23.969,
#   'Folic acid (µg DFE)': 19.0,
#   'Iron absorbed (mg)': 0.047080876,
#   'Iron (mg)': 0.941617526,
#   'Magnesium (mg)': 24.121,
#   'Niacin (mg NE)': 0.346,
#   'Pantothenic acid (mg)': 0.445144547,
#   'Vitamin A (μg RAE)': 1.898,
#   'Vitamin B1 (mg)': 0.045,
#   'Vitamin B2 (mg)': 0.136,
#   'Vitamin B6 (mg)': 0.168068,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 4.5,
#   'Zinc (mg)': 0.41},
#  'Pumpkin, raw': {'Energy (kcal)': 18,
#   'Protein (g)': 1.4,
#   'Fat (g)': 0.3,
#   'Calcium (mg)': 51.82,
#   'Folic acid (µg DFE)': 16.0,
#   'Iron absorbed (mg)': 0.035,
#   'Iron (mg)': 0.7,
#   'Magnesium (mg)': 10.0,
#   'Niacin (mg NE)': 0.8,
#   'Pantothenic acid (mg)': 0.288537415,
#   'Vitamin A (μg RAE)': 369.1666667,
#   'Vitamin B1 (mg)': 0.07,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.061,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 21.055,
#   'Zinc (mg)': 0.10675},
#  'Radish, chinese, raw': {'Energy (kcal)': 13,
#   'Protein (g)': 0.7,
#   'Fat (g)': 0.1,
#   'Calcium (mg)': 14.0,
#   'Folic acid (µg DFE)': 13.0,
#   'Iron absorbed (mg)': 0.015,
#   'Iron (mg)': 0.3,
#   'Magnesium (mg)': 11.0,
#   'Niacin (mg NE)': 0.283333333,
#   'Pantothenic acid (mg)': 0.18,
#   'Vitamin A (μg RAE)': 10.5,
#   'Vitamin B1 (mg)': 0.02,
#   'Vitamin B2 (mg)': 0.02,
#   'Vitamin B6 (mg)': 0.04,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 5.0,
#   'Zinc (mg)': 0.2},
#  'Tomato, red, ripe, raw': {'Energy (kcal)': 16,
#   'Protein (g)': 1.106,
#   'Fat (g)': 0.248,
#   'Calcium (mg)': 12.952,
#   'Folic acid (µg DFE)': 15.0,
#   'Iron absorbed (mg)': 0.009860539,
#   'Iron (mg)': 0.197210789,
#   'Magnesium (mg)': 7.418,
#   'Niacin (mg NE)': 0.6,
#   'Pantothenic acid (mg)': 0.445144547,
#   'Vitamin A (μg RAE)': 8.654416667,
#   'Vitamin B1 (mg)': 0.038,
#   'Vitamin B2 (mg)': 0.043,
#   'Vitamin B6 (mg)': 0.0485,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 12.287,
#   'Zinc (mg)': 0.41},
#  'Banana, ripe': {'Energy (kcal)': 92,
#   'Protein (g)': 1.0,
#   'Fat (g)': 0.5,
#   'Calcium (mg)': 6.0,
#   'Folic acid (µg DFE)': 19.0,
#   'Iron absorbed (mg)': 0.015,
#   'Iron (mg)': 0.3,
#   'Magnesium (mg)': 29.0,
#   'Niacin (mg NE)': 0.7,
#   'Pantothenic acid (mg)': 0.26,
#   'Vitamin A (μg RAE)': 4.0,
#   'Vitamin B1 (mg)': 0.05,
#   'Vitamin B2 (mg)': 0.1,
#   'Vitamin B6 (mg)': 0.58,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 9.0,
#   'Zinc (mg)': 0.2},
#  'Guava': {'Energy (kcal)': 51,
#   'Protein (g)': 0.8,
#   'Fat (g)': 0.6,
#   'Calcium (mg)': 20.0,
#   'Folic acid (µg DFE)': 14.0,
#   'Iron absorbed (mg)': 0.015,
#   'Iron (mg)': 0.3,
#   'Magnesium (mg)': 10.0,
#   'Niacin (mg NE)': 1.316666667,
#   'Pantothenic acid (mg)': 0.15,
#   'Vitamin A (μg RAE)': 39.5,
#   'Vitamin B1 (mg)': 0.05,
#   'Vitamin B2 (mg)': 0.05,
#   'Vitamin B6 (mg)': 0.14,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 184.0,
#   'Zinc (mg)': 0.2},
#  'Jackfruit, ripe': {'Energy (kcal)': 74,
#   'Protein (g)': 1.195,
#   'Fat (g)': 0.204,
#   'Calcium (mg)': 13.14857143,
#   'Folic acid (µg DFE)': 24.0,
#   'Iron absorbed (mg)': 0.016020113,
#   'Iron (mg)': 0.32040227,
#   'Magnesium (mg)': 42.423,
#   'Niacin (mg NE)': 0.92,
#   'Pantothenic acid (mg)': 0.178480929,
#   'Vitamin A (μg RAE)': 2.0,
#   'Vitamin B1 (mg)': 0.11,
#   'Vitamin B2 (mg)': 0.045,
#   'Vitamin B6 (mg)': 0.313423,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 3.433,
#   'Zinc (mg)': 0.589241162},
#  'Orange': {'Energy (kcal)': 44,
#   'Protein (g)': 0.68,
#   'Fat (g)': 0.2,
#   'Calcium (mg)': 23.415,
#   'Folic acid (µg DFE)': 0.0,
#   'Iron absorbed (mg)': 0.012175,
#   'Iron (mg)': 0.2435,
#   'Magnesium (mg)': 17.0,
#   'Niacin (mg NE)': 0.5,
#   'Pantothenic acid (mg)': 0.178480929,
#   'Vitamin A (μg RAE)': 18.68055556,
#   'Vitamin B1 (mg)': 0.04,
#   'Vitamin B2 (mg)': 0.01,
#   'Vitamin B6 (mg)': 0.0,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 54.0,
#   'Zinc (mg)': 0.066},
#  'Pineapple, ripe': {'Energy (kcal)': 47,
#   'Protein (g)': 0.958,
#   'Fat (g)': 0.135,
#   'Calcium (mg)': 17.88333333,
#   'Folic acid (µg DFE)': 12.1,
#   'Iron absorbed (mg)': 0.03337,
#   'Iron (mg)': 0.6674,
#   'Magnesium (mg)': 31.53333333,
#   'Niacin (mg NE)': 0.4,
#   'Pantothenic acid (mg)': 0.178480929,
#   'Vitamin A (μg RAE)': 5.091666667,
#   'Vitamin B1 (mg)': 0.2,
#   'Vitamin B2 (mg)': 0.12,
#   'Vitamin B6 (mg)': 0.09,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 33.90666667,
#   'Zinc (mg)': 0.2215},
#  'Mango, ripe': {'Energy (kcal)': 65,
#   'Protein (g)': 0.5,
#   'Fat (g)': 0.3,
#   'Calcium (mg)': 10.0,
#   'Folic acid (µg DFE)': 5.0,
#   'Iron absorbed (mg)': 0.005,
#   'Iron (mg)': 0.1,
#   'Magnesium (mg)': 9.0,
#   'Niacin (mg NE)': 0.733333333,
#   'Pantothenic acid (mg)': 0.16,
#   'Vitamin A (μg RAE)': 5.0,
#   'Vitamin B1 (mg)': 0.06,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.13,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 43.0,
#   'Zinc (mg)': 0.0},
#  'Mango, unripe': {'Energy (kcal)': 65,
#   'Protein (g)': 0.5,
#   'Fat (g)': 0.3,
#   'Calcium (mg)': 10.0,
#   'Folic acid (µg DFE)': 5.0,
#   'Iron absorbed (mg)': 0.005,
#   'Iron (mg)': 0.1,
#   'Magnesium (mg)': 9.0,
#   'Niacin (mg NE)': 0.733333333,
#   'Pantothenic acid (mg)': 0.16,
#   'Vitamin A (μg RAE)': 5.0,
#   'Vitamin B1 (mg)': 0.06,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.13,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 43.0,
#   'Zinc (mg)': 0.0},
#  'Papaya, ripe': {'Energy (kcal)': 33,
#   'Protein (g)': 0.61,
#   'Fat (g)': 0.146666667,
#   'Calcium (mg)': 28.682,
#   'Folic acid (µg DFE)': 0.0,
#   'Iron absorbed (mg)': 0.01743475,
#   'Iron (mg)': 0.348695,
#   'Magnesium (mg)': 10.31,
#   'Niacin (mg NE)': 0.488,
#   'Pantothenic acid (mg)': 0.178480929,
#   'Vitamin A (μg RAE)': 60.10583333,
#   'Vitamin B1 (mg)': 0.08,
#   'Vitamin B2 (mg)': 0.03,
#   'Vitamin B6 (mg)': 0.0,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 61.8,
#   'Zinc (mg)': 0.174},
#  'Papaya, unripe, raw': {'Energy (kcal)': 22,
#   'Protein (g)': 1.0,
#   'Fat (g)': 0.4,
#   'Calcium (mg)': 31.0,
#   'Folic acid (µg DFE)': 20.0,
#   'Iron absorbed (mg)': 0.01,
#   'Iron (mg)': 0.2,
#   'Magnesium (mg)': 8.0,
#   'Niacin (mg NE)': 0.466666667,
#   'Pantothenic acid (mg)': 0.14,
#   'Vitamin A (μg RAE)': 6.5,
#   'Vitamin B1 (mg)': 0.06,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.11,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 20.0,
#   'Zinc (mg)': 0.1},
#  'Sapote, yellow': {'Energy (kcal)': 134,
#   'Protein (g)': 1.2,
#   'Fat (g)': 0.7,
#   'Calcium (mg)': 29.0,
#   'Folic acid (µg DFE)': 18.0,
#   'Iron absorbed (mg)': 0.02,
#   'Iron (mg)': 0.4,
#   'Magnesium (mg)': 16.0,
#   'Niacin (mg NE)': 1.033333333,
#   'Pantothenic acid (mg)': 0.31,
#   'Vitamin A (μg RAE)': 23.5,
#   'Vitamin B1 (mg)': 0.08,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.1,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 35.0,
#   'Zinc (mg)': 0.1},
#  'Milk, cow, fresh': {'Energy (kcal)': 66,
#   'Protein (g)': 3.2,
#   'Fat (g)': 3.9,
#   'Calcium (mg)': 115.0,
#   'Folic acid (µg DFE)': 6.0,
#   'Iron absorbed (mg)': 0.01175,
#   'Iron (mg)': 0.1,
#   'Magnesium (mg)': 11.0,
#   'Niacin (mg NE)': 0.866666667,
#   'Pantothenic acid (mg)': 0.35,
#   'Vitamin A (μg RAE)': 55.0,
#   'Vitamin B1 (mg)': 0.04,
#   'Vitamin B2 (mg)': 0.17,
#   'Vitamin B6 (mg)': 0.06,
#   'Vitamin B12 (µg)': 0.4,
#   'Vitamin C (mg)': 1.0,
#   'Zinc (mg)': 0.4},
#  'Yogurt': {'Energy (kcal)': 61,
#   'Protein (g)': 3.47,
#   'Fat (g)': 3.25,
#   'Calcium (mg)': 121.0,
#   'Folic acid (µg DFE)': 7.0,
#   'Iron absorbed (mg)': 0.005875,
#   'Iron (mg)': 0.05,
#   'Magnesium (mg)': 12.0,
#   'Niacin (mg NE)': 0.075,
#   'Pantothenic acid (mg)': 0.389,
#   'Vitamin A (μg RAE)': 27.0,
#   'Vitamin B1 (mg)': 0.029,
#   'Vitamin B2 (mg)': 0.142,
#   'Vitamin B6 (mg)': 0.032,
#   'Vitamin B12 (µg)': 0.37,
#   'Vitamin C (mg)': 0.5,
#   'Zinc (mg)': 0.59},
#  'Egg, chicken, farmed, raw': {'Energy (kcal)': 139,
#   'Protein (g)': 14.489,
#   'Fat (g)': 9.0,
#   'Calcium (mg)': 0.0,
#   'Folic acid (µg DFE)': 50.0,
#   'Iron absorbed (mg)': 0.385,
#   'Iron (mg)': 1.54,
#   'Magnesium (mg)': 20.88,
#   'Niacin (mg NE)': 3.4,
#   'Pantothenic acid (mg)': 1.396454545,
#   'Vitamin A (μg RAE)': 165.246,
#   'Vitamin B1 (mg)': 0.184,
#   'Vitamin B2 (mg)': 0.4,
#   'Vitamin B6 (mg)': 0.149231,
#   'Vitamin B12 (µg)': 2.587272727,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 2.355250176},
#  'Egg, duck, whole, raw': {'Energy (kcal)': 188,
#   'Protein (g)': 13.48,
#   'Fat (g)': 14.29,
#   'Calcium (mg)': 65.0,
#   'Folic acid (µg DFE)': 80.0,
#   'Iron absorbed (mg)': 0.604918333,
#   'Iron (mg)': 2.419673333,
#   'Magnesium (mg)': 10.66,
#   'Niacin (mg NE)': 4.5,
#   'Pantothenic acid (mg)': 1.396454545,
#   'Vitamin A (μg RAE)': 361.7296054,
#   'Vitamin B1 (mg)': 0.12,
#   'Vitamin B2 (mg)': 0.26,
#   'Vitamin B6 (mg)': 0.25,
#   'Vitamin B12 (µg)': 2.587272727,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 1.40557},
#  'Fish, Snakehead, dried': {'Energy (kcal)': 245,
#   'Protein (g)': 53.1,
#   'Fat (g)': 2.0,
#   'Calcium (mg)': 33.0,
#   'Folic acid (µg DFE)': 28.0,
#   'Iron absorbed (mg)': 0.275,
#   'Iron (mg)': 1.1,
#   'Magnesium (mg)': 98.0,
#   'Niacin (mg NE)': 15.73333333,
#   'Pantothenic acid (mg)': 0.38,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.08,
#   'Vitamin B2 (mg)': 0.09,
#   'Vitamin B6 (mg)': 0.66,
#   'Vitamin B12 (µg)': 2.44,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 1.4},
#  'Fish, tilapia, dried': {'Energy (kcal)': 335,
#   'Protein (g)': 58.6,
#   'Fat (g)': 9.4,
#   'Calcium (mg)': 1700.0,
#   'Folic acid (µg DFE)': 28.0,
#   'Iron absorbed (mg)': 0.625,
#   'Iron (mg)': 2.5,
#   'Magnesium (mg)': 140.0,
#   'Niacin (mg NE)': 19.13333333,
#   'Pantothenic acid (mg)': 1.54,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.1,
#   'Vitamin B2 (mg)': 0.27,
#   'Vitamin B6 (mg)': 0.41,
#   'Vitamin B12 (µg)': 12.0,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 5.2},
#  'Fish, barb, pool, with bones, eyes included, raw': {'Energy (kcal)': 139,
#   'Protein (g)': 17.6,
#   'Fat (g)': 7.645,
#   'Calcium (mg)': 967.3333333,
#   'Folic acid (µg DFE)': 0.0,
#   'Iron absorbed (mg)': 0.65,
#   'Iron (mg)': 2.6,
#   'Magnesium (mg)': 0.0,
#   'Niacin (mg NE)': 0.3,
#   'Pantothenic acid (mg)': 0.602327623,
#   'Vitamin A (μg RAE)': 59.07052083,
#   'Vitamin B1 (mg)': 0.01,
#   'Vitamin B2 (mg)': 0.03,
#   'Vitamin B6 (mg)': 0.262062552,
#   'Vitamin B12 (µg)': 3.415776701,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 3.0},
#  'Fish, catfish, raw': {'Energy (kcal)': 117,
#   'Protein (g)': 16.33,
#   'Fat (g)': 5.7,
#   'Calcium (mg)': 38.0,
#   'Folic acid (µg DFE)': 8.0,
#   'Iron absorbed (mg)': 0.225,
#   'Iron (mg)': 0.9,
#   'Magnesium (mg)': 30.0,
#   'Niacin (mg NE)': 1.4,
#   'Pantothenic acid (mg)': 0.602327623,
#   'Vitamin A (μg RAE)': 25.0,
#   'Vitamin B1 (mg)': 0.12,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.29,
#   'Vitamin B12 (µg)': 2.3,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 0.6},
#  'Fish, days mystus, eyes included, raw': {'Energy (kcal)': 114,
#   'Protein (g)': 18.18333333,
#   'Fat (g)': 4.564285714,
#   'Calcium (mg)': 627.25,
#   'Folic acid (µg DFE)': 0.0,
#   'Iron absorbed (mg)': 0.688,
#   'Iron (mg)': 2.752,
#   'Magnesium (mg)': 22.09,
#   'Niacin (mg NE)': 1.954014403,
#   'Pantothenic acid (mg)': 0.602327623,
#   'Vitamin A (μg RAE)': 43.32987452,
#   'Vitamin B1 (mg)': 0.01,
#   'Vitamin B2 (mg)': 0.04,
#   'Vitamin B6 (mg)': 0.295645693,
#   'Vitamin B12 (µg)': 3.415776701,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 0.77},
#  'Fish, gouramy, eyes included, raw': {'Energy (kcal)': 105,
#   'Protein (g)': 15.8325,
#   'Fat (g)': 4.576666667,
#   'Calcium (mg)': 421.6666667,
#   'Folic acid (µg DFE)': 0.0,
#   'Iron absorbed (mg)': 0.2275,
#   'Iron (mg)': 0.91,
#   'Magnesium (mg)': 35.80932491,
#   'Niacin (mg NE)': 5.558423326,
#   'Pantothenic acid (mg)': 0.602327623,
#   'Vitamin A (μg RAE)': 38.66666667,
#   'Vitamin B1 (mg)': 0.082260269,
#   'Vitamin B2 (mg)': 0.09453042,
#   'Vitamin B6 (mg)': 0.277828235,
#   'Vitamin B12 (µg)': 3.415776701,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 1.35},
#  'Fish, small, fresh, fresh water': {'Energy (kcal)': 84,
#   'Protein (g)': 14.8,
#   'Fat (g)': 2.3,
#   'Calcium (mg)': 9.0,
#   'Folic acid (µg DFE)': 8.0,
#   'Iron absorbed (mg)': 0.075,
#   'Iron (mg)': 0.3,
#   'Magnesium (mg)': 22.0,
#   'Niacin (mg NE)': 4.666666667,
#   'Pantothenic acid (mg)': 0.73,
#   'Vitamin A (μg RAE)': 12.0,
#   'Vitamin B1 (mg)': 0.18,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.09,
#   'Vitamin B12 (µg)': 2.32,
#   'Vitamin C (mg)': 1.0,
#   'Zinc (mg)': 0.5},
#  'Fish, snakehead, striped, raw': {'Energy (kcal)': 101,
#   'Protein (g)': 17.7425,
#   'Fat (g)': 3.3,
#   'Calcium (mg)': 103.82,
#   'Folic acid (µg DFE)': 0.0,
#   'Iron absorbed (mg)': 0.2603125,
#   'Iron (mg)': 1.04125,
#   'Magnesium (mg)': 42.65,
#   'Niacin (mg NE)': 8.026843833,
#   'Pantothenic acid (mg)': 0.602327623,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.04,
#   'Vitamin B2 (mg)': 0.05,
#   'Vitamin B6 (mg)': 0.241642638,
#   'Vitamin B12 (µg)': 3.415776701,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 0.305714286},
#  'Fish, tilapia, raw': {'Energy (kcal)': 96,
#   'Protein (g)': 20.08,
#   'Fat (g)': 1.7,
#   'Calcium (mg)': 10.0,
#   'Folic acid (µg DFE)': 24.0,
#   'Iron absorbed (mg)': 0.14,
#   'Iron (mg)': 0.56,
#   'Magnesium (mg)': 27.0,
#   'Niacin (mg NE)': 3.903,
#   'Pantothenic acid (mg)': 0.487,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.041,
#   'Vitamin B2 (mg)': 0.063,
#   'Vitamin B6 (mg)': 0.162,
#   'Vitamin B12 (µg)': 1.58,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 0.33},
#  'Fish paste, red, fermented': {'Energy (kcal)': 105,
#   'Protein (g)': 18.5,
#   'Fat (g)': 2.9,
#   'Calcium (mg)': 12.0,
#   'Folic acid (µg DFE)': 10.0,
#   'Iron absorbed (mg)': 0.1,
#   'Iron (mg)': 0.4,
#   'Magnesium (mg)': 28.0,
#   'Niacin (mg NE)': 5.85,
#   'Pantothenic acid (mg)': 0.91,
#   'Vitamin A (μg RAE)': 15.0,
#   'Vitamin B1 (mg)': 0.23,
#   'Vitamin B2 (mg)': 0.07,
#   'Vitamin B6 (mg)': 0.11,
#   'Vitamin B12 (µg)': 2.9,
#   'Vitamin C (mg)': 1.0,
#   'Zinc (mg)': 0.6},
#  'Shrimp, raw': {'Energy (kcal)': 79,
#   'Protein (g)': 16.7,
#   'Fat (g)': 0.9,
#   'Calcium (mg)': 31.0,
#   'Folic acid (µg DFE)': 3.0,
#   'Iron absorbed (mg)': 0.625,
#   'Iron (mg)': 2.5,
#   'Magnesium (mg)': 27.0,
#   'Niacin (mg NE)': 5.983333333,
#   'Pantothenic acid (mg)': 0.8,
#   'Vitamin A (μg RAE)': 51.0,
#   'Vitamin B1 (mg)': 0.02,
#   'Vitamin B2 (mg)': 0.02,
#   'Vitamin B6 (mg)': 0.1,
#   'Vitamin B12 (µg)': 1.19,
#   'Vitamin C (mg)': 2.0,
#   'Zinc (mg)': 1.3},
#  'Squid, raw': {'Energy (kcal)': 147,
#   'Protein (g)': 25.0,
#   'Fat (g)': 2.2,
#   'Calcium (mg)': 51.0,
#   'Folic acid (µg DFE)': 3.0,
#   'Iron absorbed (mg)': 0.275,
#   'Iron (mg)': 1.1,
#   'Magnesium (mg)': 53.0,
#   'Niacin (mg NE)': 7.933333333,
#   'Pantothenic acid (mg)': 0.32,
#   'Vitamin A (μg RAE)': 8.0,
#   'Vitamin B1 (mg)': 0.03,
#   'Vitamin B2 (mg)': 0.66,
#   'Vitamin B6 (mg)': 0.09,
#   'Vitamin B12 (µg)': 2.08,
#   'Vitamin C (mg)': 7.0,
#   'Zinc (mg)': 2.5},
#  'Chicken, liver, raw': {'Energy (kcal)': 114,
#   'Protein (g)': 16.92,
#   'Fat (g)': 4.83,
#   'Calcium (mg)': 18.35,
#   'Folic acid (µg DFE)': 588.0,
#   'Iron absorbed (mg)': 2.2475,
#   'Iron (mg)': 8.99,
#   'Magnesium (mg)': 19.0,
#   'Niacin (mg NE)': 8.77,
#   'Pantothenic acid (mg)': 1.844013793,
#   'Vitamin A (μg RAE)': 3295.583333,
#   'Vitamin B1 (mg)': 0.305,
#   'Vitamin B2 (mg)': 1.778,
#   'Vitamin B6 (mg)': 0.853,
#   'Vitamin B12 (µg)': 16.76303448,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 2.495},
#  'Chicken, meat': {'Energy (kcal)': 285,
#   'Protein (g)': 26.9,
#   'Fat (g)': 18.9,
#   'Calcium (mg)': 13.0,
#   'Folic acid (µg DFE)': 5.0,
#   'Iron absorbed (mg)': 0.35,
#   'Iron (mg)': 1.4,
#   'Magnesium (mg)': 20.0,
#   'Niacin (mg NE)': 10.81666667,
#   'Pantothenic acid (mg)': 0.75,
#   'Vitamin A (μg RAE)': 39.0,
#   'Vitamin B1 (mg)': 0.09,
#   'Vitamin B2 (mg)': 0.24,
#   'Vitamin B6 (mg)': 0.25,
#   'Vitamin B12 (µg)': 0.23,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 1.8},
#  'Duck, liver, raw': {'Energy (kcal)': 136,
#   'Protein (g)': 18.74,
#   'Fat (g)': 4.64,
#   'Calcium (mg)': 11.0,
#   'Folic acid (µg DFE)': 738.0,
#   'Iron absorbed (mg)': 7.6325,
#   'Iron (mg)': 30.53,
#   'Magnesium (mg)': 24.0,
#   'Niacin (mg NE)': 6.5,
#   'Pantothenic acid (mg)': 6.184,
#   'Vitamin A (μg RAE)': 11984.0,
#   'Vitamin B1 (mg)': 0.562,
#   'Vitamin B2 (mg)': 0.892,
#   'Vitamin B6 (mg)': 0.76,
#   'Vitamin B12 (µg)': 54.0,
#   'Vitamin C (mg)': 4.5,
#   'Zinc (mg)': 3.07},
#  'Duck, meat, raw': {'Energy (kcal)': 130,
#   'Protein (g)': 21.6,
#   'Fat (g)': 4.8,
#   'Calcium (mg)': 4.0,
#   'Folic acid (µg DFE)': 25.0,
#   'Iron absorbed (mg)': 0.6,
#   'Iron (mg)': 2.4,
#   'Magnesium (mg)': 19.0,
#   'Niacin (mg NE)': 1.2,
#   'Pantothenic acid (mg)': 0.747391753,
#   'Vitamin A (μg RAE)': 24.0,
#   'Vitamin B1 (mg)': 0.36,
#   'Vitamin B2 (mg)': 0.45,
#   'Vitamin B6 (mg)': 0.34,
#   'Vitamin B12 (µg)': 1.878979592,
#   'Vitamin C (mg)': 17.9,
#   'Zinc (mg)': 1.9},
#  'Quail, meat': {'Energy (kcal)': 208,
#   'Protein (g)': 28.1,
#   'Fat (g)': 9.7,
#   'Calcium (mg)': 26.0,
#   'Folic acid (µg DFE)': 7.0,
#   'Iron absorbed (mg)': 0.45,
#   'Iron (mg)': 1.8,
#   'Magnesium (mg)': 25.0,
#   'Niacin (mg NE)': 10.28333333,
#   'Pantothenic acid (mg)': 0.86,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.06,
#   'Vitamin B2 (mg)': 0.18,
#   'Vitamin B6 (mg)': 0.41,
#   'Vitamin B12 (µg)': 0.35,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 3.0},
#  'Beef, blood, coagulated': {'Energy (kcal)': 145,
#   'Protein (g)': 25.1,
#   'Fat (g)': 4.2,
#   'Calcium (mg)': 12.0,
#   'Folic acid (µg DFE)': 4.0,
#   'Iron absorbed (mg)': 9.85,
#   'Iron (mg)': 39.4,
#   'Magnesium (mg)': 19.0,
#   'Niacin (mg NE)': 9.95,
#   'Pantothenic acid (mg)': 0.88,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.05,
#   'Vitamin B2 (mg)': 0.3,
#   'Vitamin B6 (mg)': 0.04,
#   'Vitamin B12 (µg)': 5.02,
#   'Vitamin C (mg)': 50.0,
#   'Zinc (mg)': 2.8},
#  'Beef, liver, raw': {'Energy (kcal)': 130,
#   'Protein (g)': 20.36,
#   'Fat (g)': 3.63,
#   'Calcium (mg)': 4.045,
#   'Folic acid (µg DFE)': 290.0,
#   'Iron absorbed (mg)': 0.875,
#   'Iron (mg)': 3.5,
#   'Magnesium (mg)': 18.0,
#   'Niacin (mg NE)': 10.03,
#   'Pantothenic acid (mg)': 1.844013793,
#   'Vitamin A (μg RAE)': 4968.333333,
#   'Vitamin B1 (mg)': 0.189,
#   'Vitamin B2 (mg)': 2.755,
#   'Vitamin B6 (mg)': 1.083,
#   'Vitamin B12 (µg)': 16.76303448,
#   'Vitamin C (mg)': 2.247367582,
#   'Zinc (mg)': 3.705},
#  'Beef, meat, lean, boneless, raw': {'Energy (kcal)': 103,
#   'Protein (g)': 20.7425,
#   'Fat (g)': 2.255,
#   'Calcium (mg)': 4.259230769,
#   'Folic acid (µg DFE)': 7.0,
#   'Iron absorbed (mg)': 0.494615385,
#   'Iron (mg)': 1.978461538,
#   'Magnesium (mg)': 15.31,
#   'Niacin (mg NE)': 9.27,
#   'Pantothenic acid (mg)': 0.551861789,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.06,
#   'Vitamin B2 (mg)': 0.19,
#   'Vitamin B6 (mg)': 0.32,
#   'Vitamin B12 (µg)': 1.977235772,
#   'Vitamin C (mg)': 1.3,
#   'Zinc (mg)': 3.518181818},
#  'Pork or Goat, blood, coagulated': {'Energy (kcal)': 116,
#   'Protein (g)': 20.1,
#   'Fat (g)': 3.4,
#   'Calcium (mg)': 10.0,
#   'Folic acid (µg DFE)': 3.0,
#   'Iron absorbed (mg)': 7.875,
#   'Iron (mg)': 31.5,
#   'Magnesium (mg)': 15.0,
#   'Niacin (mg NE)': 7.983333333,
#   'Pantothenic acid (mg)': 0.7,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.04,
#   'Vitamin B2 (mg)': 0.24,
#   'Vitamin B6 (mg)': 0.03,
#   'Vitamin B12 (µg)': 4.02,
#   'Vitamin C (mg)': 40.0,
#   'Zinc (mg)': 2.2},
#  'Pork, back ribs, raw': {'Energy (kcal)': 224,
#   'Protein (g)': 19.07,
#   'Fat (g)': 16.33,
#   'Calcium (mg)': 31.0,
#   'Folic acid (µg DFE)': 0.0,
#   'Iron absorbed (mg)': 0.19,
#   'Iron (mg)': 0.76,
#   'Magnesium (mg)': 16.0,
#   'Niacin (mg NE)': 6.776,
#   'Pantothenic acid (mg)': 0.818,
#   'Vitamin A (μg RAE)': 7.0,
#   'Vitamin B1 (mg)': 0.457,
#   'Vitamin B2 (mg)': 0.305,
#   'Vitamin B6 (mg)': 0.422,
#   'Vitamin B12 (µg)': 0.56,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 2.54},
#  'Pork, liver, raw': {'Energy (kcal)': 134,
#   'Protein (g)': 21.39,
#   'Fat (g)': 3.65,
#   'Calcium (mg)': 9.0,
#   'Folic acid (µg DFE)': 212.0,
#   'Iron absorbed (mg)': 5.825,
#   'Iron (mg)': 23.3,
#   'Magnesium (mg)': 18.0,
#   'Niacin (mg NE)': 15.301,
#   'Pantothenic acid (mg)': 6.65,
#   'Vitamin A (μg RAE)': 6502.0,
#   'Vitamin B1 (mg)': 0.283,
#   'Vitamin B2 (mg)': 3.005,
#   'Vitamin B6 (mg)': 0.69,
#   'Vitamin B12 (µg)': 26.0,
#   'Vitamin C (mg)': 25.3,
#   'Zinc (mg)': 5.76},
#  'Pork, meat, raw': {'Energy (kcal)': 211,
#   'Protein (g)': 18.22,
#   'Fat (g)': 14.79,
#   'Calcium (mg)': 11.0,
#   'Folic acid (µg DFE)': 3.0,
#   'Iron absorbed (mg)': 0.2225,
#   'Iron (mg)': 0.89,
#   'Magnesium (mg)': 21.0,
#   'Niacin (mg NE)': 4.73,
#   'Pantothenic acid (mg)': 0.899,
#   'Vitamin A (μg RAE)': 1.0,
#   'Vitamin B1 (mg)': 0.622,
#   'Vitamin B2 (mg)': 0.255,
#   'Vitamin B6 (mg)': 0.504,
#   'Vitamin B12 (µg)': 0.67,
#   'Vitamin C (mg)': 0.3,
#   'Zinc (mg)': 2.27},
#  'Bean, kidney, dried, raw': {'Energy (kcal)': 326,
#   'Protein (g)': 22.4,
#   'Fat (g)': 1.3,
#   'Calcium (mg)': 72.0,
#   'Folic acid (µg DFE)': 334.0,
#   'Iron absorbed (mg)': 0.375,
#   'Iron (mg)': 7.5,
#   'Magnesium (mg)': 116.0,
#   'Niacin (mg NE)': 5.916666667,
#   'Pantothenic acid (mg)': 0.57,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.41,
#   'Vitamin B2 (mg)': 0.15,
#   'Vitamin B6 (mg)': 0.31,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 3.0,
#   'Zinc (mg)': 2.8},
#  'Bean, mung, dry': {'Energy (kcal)': 116,
#   'Protein (g)': 7.7,
#   'Fat (g)': 0.5,
#   'Calcium (mg)': 24.0,
#   'Folic acid (µg DFE)': 208.0,
#   'Iron absorbed (mg)': 0.125,
#   'Iron (mg)': 2.5,
#   'Magnesium (mg)': 53.0,
#   'Niacin (mg NE)': 2.083333333,
#   'Pantothenic acid (mg)': 0.41,
#   'Vitamin A (μg RAE)': 1.0,
#   'Vitamin B1 (mg)': 0.2,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.1,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 1.3},
#  'Beansprout, mung bean, raw': {'Energy (kcal)': 61,
#   'Protein (g)': 6.6,
#   'Fat (g)': 3.4,
#   'Calcium (mg)': 34.0,
#   'Folic acid (µg DFE)': 86.0,
#   'Iron absorbed (mg)': 0.055,
#   'Iron (mg)': 1.1,
#   'Magnesium (mg)': 36.0,
#   'Niacin (mg NE)': 1.933333333,
#   'Pantothenic acid (mg)': 0.47,
#   'Vitamin A (μg RAE)': 0.5,
#   'Vitamin B1 (mg)': 0.17,
#   'Vitamin B2 (mg)': 0.06,
#   'Vitamin B6 (mg)': 0.09,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 8.0,
#   'Zinc (mg)': 0.6},
#  'Peanut, without shell': {'Energy (kcal)': 567,
#   'Protein (g)': 25.8,
#   'Fat (g)': 49.2,
#   'Calcium (mg)': 92.0,
#   'Folic acid (µg DFE)': 126.0,
#   'Iron absorbed (mg)': 0.23,
#   'Iron (mg)': 4.6,
#   'Magnesium (mg)': 168.0,
#   'Niacin (mg NE)': 18.46666667,
#   'Pantothenic acid (mg)': 1.39,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.25,
#   'Vitamin B2 (mg)': 0.11,
#   'Vitamin B6 (mg)': 0.26,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 3.3},
#  'Soybean, dried, raw': {'Energy (kcal)': 424,
#   'Protein (g)': 32.93680267,
#   'Fat (g)': 19.94,
#   'Calcium (mg)': 240.565,
#   'Folic acid (µg DFE)': 100.0,
#   'Iron absorbed (mg)': 0.567,
#   'Iron (mg)': 11.34,
#   'Magnesium (mg)': 207.0,
#   'Niacin (mg NE)': 7.9,
#   'Pantothenic acid (mg)': 0.502999008,
#   'Vitamin A (μg RAE)': 1.083333333,
#   'Vitamin B1 (mg)': 0.73,
#   'Vitamin B2 (mg)': 0.5,
#   'Vitamin B6 (mg)': 0.417,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 5.7},
#  'Tofu': {'Energy (kcal)': 76,
#   'Protein (g)': 8.1,
#   'Fat (g)': 4.8,
#   'Calcium (mg)': 105.0,
#   'Folic acid (µg DFE)': 15.0,
#   'Iron absorbed (mg)': 0.27,
#   'Iron (mg)': 5.4,
#   'Magnesium (mg)': 103.0,
#   'Niacin (mg NE)': 2.3,
#   'Pantothenic acid (mg)': 0.07,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.08,
#   'Vitamin B2 (mg)': 0.05,
#   'Vitamin B6 (mg)': 0.05,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 0.8},
#  'Butter, CotD': {'Energy (kcal)': 710,
#   'Protein (g)': 0.2,
#   'Fat (g)': 80.6,
#   'Calcium (mg)': 6.0,
#   'Folic acid (µg DFE)': 1.0,
#   'Iron absorbed (mg)': 0.025,
#   'Iron (mg)': 0.1,
#   'Magnesium (mg)': 1.0,
#   'Niacin (mg NE)': 0.05,
#   'Pantothenic acid (mg)': 0.03,
#   'Vitamin A (μg RAE)': 749.0,
#   'Vitamin B1 (mg)': 0.0,
#   'Vitamin B2 (mg)': 0.01,
#   'Vitamin B6 (mg)': 0.0,
#   'Vitamin B12 (µg)': 0.03,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 0.0},
#  'Oil, vegetable': {'Energy (kcal)': 862,
#   'Protein (g)': 0.0,
#   'Fat (g)': 100.0,
#   'Calcium (mg)': 0.0,
#   'Folic acid (µg DFE)': 0.0,
#   'Iron absorbed (mg)': 0.0,
#   'Iron (mg)': 0.0,
#   'Magnesium (mg)': 0.0,
#   'Niacin (mg NE)': 0.0,
#   'Pantothenic acid (mg)': 0.0,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.0,
#   'Vitamin B2 (mg)': 0.0,
#   'Vitamin B6 (mg)': 0.0,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 0.0},
#  'Sugar, palm': {'Energy (kcal)': 369,
#   'Protein (g)': 0.6,
#   'Fat (g)': 0.0,
#   'Calcium (mg)': 377.0,
#   'Folic acid (µg DFE)': 1.0,
#   'Iron absorbed (mg)': 0.09,
#   'Iron (mg)': 1.8,
#   'Magnesium (mg)': 22.0,
#   'Niacin (mg NE)': 0.2,
#   'Pantothenic acid (mg)': 0.11,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.01,
#   'Vitamin B2 (mg)': 0.01,
#   'Vitamin B6 (mg)': 0.03,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 0.3},
#  'Sugar, white': {'Energy (kcal)': 398,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Calcium (mg)': 12.0,
#   'Folic acid (µg DFE)': 0.0,
#   'Iron absorbed (mg)': 0.008,
#   'Iron (mg)': 0.16,
#   'Magnesium (mg)': 2.0,
#   'Niacin (mg NE)': 0.0,
#   'Pantothenic acid (mg)': 0.321084337,
#   'Vitamin A (μg RAE)': 0.0,
#   'Vitamin B1 (mg)': 0.0,
#   'Vitamin B2 (mg)': 0.0,
#   'Vitamin B6 (mg)': 0.0,
#   'Vitamin B12 (µg)': 0.0,
#   'Vitamin C (mg)': 0.0,
#   'Zinc (mg)': 0.1}}

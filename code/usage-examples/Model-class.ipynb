# %%
import os
import sys
import pandas as pd
import numpy as np

# Set up directories
code_dir = os.path.dirname(os.getcwd())
classes_dir = os.path.join(code_dir, 'classes')
project_dir = os.path.dirname(code_dir)
data_dir = os.path.join(project_dir, 'data')

# Add classes directory to sys.path
sys.path.append(classes_dir)

# Import custom classes
from DATA import Data
from MODEL import Model

# %%
# Specify the population group and region
population_group = 'Woman, 18-29y'
region = 'Kampot and Kep'

# %%
data = Data(data_dir)
model = Model(data, population_group, region)

# %%
model.pulp_model
# Out:
# molp-food-basket:
# MINIMIZE
# None
# SUBJECT TO
# Cost_(KHR.day): Cost_(KHR.day) - 3.49275362319 x_Banana,_ripe
#  - 2.82 x_Banana_flower_heart - 6.33 x_Bean,_kidney,_dried,_raw
#  - 6.33 x_Bean,_mung,_dry
#  - 3.81927710843 x_Bean,_yard_long_bean,_immature,_raw
#  - 2.72 x_Beansprout,_mung_bean,_raw - 3.83 x_Beef,_blood,_coagulated
#  - 26.44 x_Beef,_liver,_raw - 29.78 x_Beef,_meat,_lean,_boneless,_raw
#  - 21.67 x_Butter,_CotD - 4.18823529412 x_Cabbage,_chinese,_pak_choi,_raw
#  - 4.44705882353 x_Cabbage,_chinese,_pe_tsai,_raw
#  - 6.02380952381 x_Cabbage,_chinese,_raw - 4.32558139535 x_Carrot,_raw
#  - 1.78571428571 x_Cassava,_white - 12.4666666667 x_Cauliflower,_raw
#  - 10.22 x_Chicken,_liver,_raw - 12.3108108108 x_Chicken,_meat
#  - 2.86315789474 x_Cucumber,_raw - 12.306122449 x_Duck,_liver,_raw
#  - 16.5833333333 x_Duck,_meat,_raw - 11.0804597701 x_Egg,_chicken,_farmed,_raw
#  - 9.55056179775 x_Egg,_duck,_whole,_raw - 3.56790123457 x_Eggplant,_purple
#  - 3.97530864198 x_Eggplant,_raw - 22.33 x_Fish,_Snakehead,_dried
#  - 11.17 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  - 13.4615384615 x_Fish,_catfish,_raw
#  - 17.0731707317 x_Fish,_days_mystus,_eyes_included,_raw
#  - 18.9122807018 x_Fish,_gouramy,_eyes_included,_raw
#  - 10.33 x_Fish,_small,_fresh,_fresh_water
#  - 13.8571428571 x_Fish,_snakehead,_striped,_raw - 20 x_Fish,_tilapia,_dried
#  - 20.6041666667 x_Fish,_tilapia,_raw - 11 x_Fish_paste,_red,_fermented
#  - 3.56842105263 x_Gourd,_bitter,_raw - 3.25609756098 x_Gourd,_ridge,_raw
#  - 2.84042553191 x_Gourd,_sponge,_raw - 2.42528735632 x_Gourd,_wax
#  - 4.70512820513 x_Guava - 8.38157894737 x_Ivygourd,_leaf,_raw
#  - 15.1621621622 x_Jackfruit,_ripe - 4.17 x_Kale,_raw
#  - 5.27848101266 x_Leaf,_amaranth,_spiney,_raw
#  - 4.52631578947 x_Leaf,_bitter_gourd,_raw - 6.96 x_Leaf,_drumstick,_raw
#  - 4.02631578947 x_Leaf,_greens,_mustard
#  - 4.68421052632 x_Leaf,_mustard_spinach,_raw
#  - 5.25352112676 x_Leaf,_pumpkin,_raw - 3.3768115942 x_Mango,_ripe
#  - 2.8115942029 x_Mango,_unripe - 12.15 x_Milk,_cow,_fresh
#  - 59.44 x_Mushrooms,_shiitake,_dried - 30.51 x_Mushrooms,_shiitake,_raw
#  - 8.88 x_Noodles,_egg,_dry,_enriched - 2.44 x_Noodles,_rice,_cooked
#  - 7.47 x_Oil,_vegetable - 4.27586206897 x_Onion,_raw - 8.11940298507 x_Orange
#  - 3.62666666667 x_Papaya,_ripe - 2.08695652174 x_Papaya,_unripe,_raw
#  - 8 x_Peanut,_without_shell - 4.01612903226 x_Pineapple,_ripe
#  - 3.15384615385 x_Plantain,_all_varieties
#  - 32.8550724638 x_Pork,_back_ribs,_raw - 22.8979591837 x_Pork,_liver,_raw
#  - 32.3623188406 x_Pork,_meat,_raw - 3.33 x_Pork_or_Goat,_blood,_coagulated
#  - 2.41772151899 x_Pumpkin,_raw - 23.4626865672 x_Quail,_meat
#  - 3.20202020202 x_Radish,_chinese,_raw - 2.07 x_Rice,_white,_polished,_raw
#  - 27.22 x_Shrimp,_raw - 6.22 x_Soybean,_dried,_raw
#  - 24.7058823529 x_Squid,_raw - 5 x_Sugar,_palm - 2.97 x_Sugar,_white
#  - 3.10714285714 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  - 2.66666666667 x_Sweet_potato,_white_flesh,_raw
#  - 6.13953488372 x_Taro,_tuber,_raw - 5.29 x_Tofu
#  - 3.68104312939 x_Tomato,_red,_ripe,_raw - 3.69014084507 x_Water_spinach,_raw
#  - 2.5119047619 x_Yam_bean,_jicama,_raw - 7.31 x_Yogurt = 0
#
# Dietary_shift_index_(unitless): Dietary_shift_index_(unitless)
#  - 0.00717351057582 z_lower_Fats_and_oils_(general)
#  - 0.00178086801345 z_lower_Freshwater_fish
#  - 0.00146204575553 z_lower_Leafy_vegetables
#  - 0.00112527599941 z_lower_Other_vegetables - 0.000485695528773 z_lower_Rice
#  - 0.00559067427198 z_lower_Sugars
#  - 0.000598254390247 z_lower_Yellow_and_orange_fruits
#  - 0.00463297150743 z_upper_Eggs
#  - 0.00717351057582 z_upper_Fats_and_oils_(general)
#  - 0.00197816126534 z_upper_Fish_(dried)
#  - 0.00178086801345 z_upper_Freshwater_fish
#  - 0.000369212616035 z_upper_Fruits_(other)
#  - 0.00146204575553 z_upper_Leafy_vegetables
#  - 0.00270827405969 z_upper_Milk_and_milk_products_(general)
#  - 0.00199755417982 z_upper_Other_and_mixed_cereals
#  - 0.00112527599941 z_upper_Other_vegetables
#  - 0.00147834089904 z_upper_Poultry
#  - 0.00455843054551 z_upper_Processed_fish_and_shellfish
#  - 0.00549387052701 z_upper_Pulses,_seeds_and_nuts_(general)
#  - 0.00207222071286 z_upper_Red_meat_mammals,_reptiles_and_amphibians
#  - 0.000485695528773 z_upper_Rice
#  - 0.003028320214 z_upper_Roots,_tubers_and_plantains_(general)
#  - 0.00559067427198 z_upper_Sugars
#  - 0.000598254390247 z_upper_Yellow_and_orange_fruits = 0
#
# CO2e_(Kg.day): CO2e_(Kg.day) - 0.00086 x_Banana,_ripe
#  - 0.00053 x_Banana_flower_heart - 0.00179 x_Bean,_kidney,_dried,_raw
#  - 0.00179 x_Bean,_mung,_dry - 0.00053 x_Bean,_yard_long_bean,_immature,_raw
#  - 0.00179 x_Beansprout,_mung_bean,_raw - 0.09948 x_Beef,_blood,_coagulated
#  - 0.09948 x_Beef,_liver,_raw - 0.09948 x_Beef,_meat,_lean,_boneless,_raw
#  - 0.00315 x_Butter,_CotD - 0.00051 x_Cabbage,_chinese,_pak_choi,_raw
#  - 0.00051 x_Cabbage,_chinese,_pe_tsai,_raw - 0.00051 x_Cabbage,_chinese,_raw
#  - 0.00043 x_Carrot,_raw - 0.00132 x_Cassava,_white
#  - 0.00051 x_Cauliflower,_raw - 0.00987 x_Chicken,_liver,_raw
#  - 0.00987 x_Chicken,_meat - 0.00053 x_Cucumber,_raw
#  - 0.00987 x_Duck,_liver,_raw - 0.00987 x_Duck,_meat,_raw
#  - 0.00467 x_Egg,_chicken,_farmed,_raw - 0.00467 x_Egg,_duck,_whole,_raw
#  - 0.00053 x_Eggplant,_purple - 0.00053 x_Eggplant,_raw
#  - 0.01363 x_Fish,_Snakehead,_dried
#  - 0.00735 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  - 0.00735 x_Fish,_catfish,_raw
#  - 0.00735 x_Fish,_days_mystus,_eyes_included,_raw
#  - 0.00735 x_Fish,_gouramy,_eyes_included,_raw
#  - 0.00735 x_Fish,_small,_fresh,_fresh_water
#  - 0.00735 x_Fish,_snakehead,_striped,_raw - 0.01363 x_Fish,_tilapia,_dried
#  - 0.00735 x_Fish,_tilapia,_raw - 0.01363 x_Fish_paste,_red,_fermented
#  - 0.00053 x_Gourd,_bitter,_raw - 0.00053 x_Gourd,_ridge,_raw
#  - 0.00053 x_Gourd,_sponge,_raw - 0.00053 x_Gourd,_wax - 0.00105 x_Guava
#  - 0.00053 x_Ivygourd,_leaf,_raw - 0.00105 x_Jackfruit,_ripe
#  - 0.00051 x_Kale,_raw - 0.00053 x_Leaf,_amaranth,_spiney,_raw
#  - 0.00053 x_Leaf,_bitter_gourd,_raw - 0.00053 x_Leaf,_drumstick,_raw
#  - 0.00053 x_Leaf,_greens,_mustard - 0.00053 x_Leaf,_mustard_spinach,_raw
#  - 0.00053 x_Leaf,_pumpkin,_raw - 0.00105 x_Mango,_ripe
#  - 0.00105 x_Mango,_unripe - 0.02388 x_Milk,_cow,_fresh
#  - 0.00053 x_Mushrooms,_shiitake,_dried - 0.00053 x_Mushrooms,_shiitake,_raw
#  - 0.001918633088 x_Noodles,_egg,_dry,_enriched
#  - 0.00914503822652 x_Noodles,_rice,_cooked - 0.005286 x_Oil,_vegetable
#  - 0.0005 x_Onion,_raw - 0.00039 x_Orange - 0.00105 x_Papaya,_ripe
#  - 0.00105 x_Papaya,_unripe,_raw - 0.00043 x_Peanut,_without_shell
#  - 0.00105 x_Pineapple,_ripe - 0.00086 x_Plantain,_all_varieties
#  - 0.01231 x_Pork,_back_ribs,_raw - 0.01231 x_Pork,_liver,_raw
#  - 0.01231 x_Pork,_meat,_raw - 0.03972 x_Pork_or_Goat,_blood,_coagulated
#  - 0.00053 x_Pumpkin,_raw - 0.00987 x_Quail,_meat
#  - 0.00051 x_Radish,_chinese,_raw
#  - 0.00914503822652 x_Rice,_white,_polished,_raw - 0.02687 x_Shrimp,_raw
#  - 0.00179 x_Soybean,_dried,_raw - 0.02687 x_Squid,_raw - 0.0032 x_Sugar,_palm
#  - 0.0032 x_Sugar,_white
#  - 0.00046 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  - 0.00046 x_Sweet_potato,_white_flesh,_raw - 0.00043 x_Taro,_tuber,_raw
#  - 0.00316 x_Tofu - 0.00209 x_Tomato,_red,_ripe,_raw
#  - 0.00053 x_Water_spinach,_raw - 0.00043 x_Yam_bean,_jicama,_raw
#  - 0.02388 x_Yogurt = 0
#
# nutrient_Energy_(kcal)_lower: 0.92 x_Banana,_ripe + 0.21 x_Banana_flower_heart
#  + 3.26 x_Bean,_kidney,_dried,_raw + 1.16 x_Bean,_mung,_dry
#  + 0.47 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.61 x_Beansprout,_mung_bean,_raw + 1.45 x_Beef,_blood,_coagulated
#  + 1.3 x_Beef,_liver,_raw + 1.03 x_Beef,_meat,_lean,_boneless,_raw
#  + 7.1 x_Butter,_CotD + 0.13 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.16 x_Cabbage,_chinese,_pe_tsai,_raw + 0.15 x_Cabbage,_chinese,_raw
#  + 0.45 x_Carrot,_raw + 1.31 x_Cassava,_white + 0.25 x_Cauliflower,_raw
#  + 1.14 x_Chicken,_liver,_raw + 2.85 x_Chicken,_meat + 0.13 x_Cucumber,_raw
#  + 1.36 x_Duck,_liver,_raw + 1.3 x_Duck,_meat,_raw
#  + 1.39 x_Egg,_chicken,_farmed,_raw + 1.88 x_Egg,_duck,_whole,_raw
#  + 0.28 x_Eggplant,_purple + 0.25 x_Eggplant,_raw
#  + 2.45 x_Fish,_Snakehead,_dried
#  + 1.39 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 1.17 x_Fish,_catfish,_raw + 1.14 x_Fish,_days_mystus,_eyes_included,_raw
#  + 1.05 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.84 x_Fish,_small,_fresh,_fresh_water
#  + 1.01 x_Fish,_snakehead,_striped,_raw + 3.35 x_Fish,_tilapia,_dried
#  + 0.96 x_Fish,_tilapia,_raw + 1.05 x_Fish_paste,_red,_fermented
#  + 0.31 x_Gourd,_bitter,_raw + 0.29 x_Gourd,_ridge,_raw
#  + 0.24 x_Gourd,_sponge,_raw + 0.2 x_Gourd,_wax + 0.51 x_Guava
#  + 0.37 x_Ivygourd,_leaf,_raw + 0.74 x_Jackfruit,_ripe + 0.49 x_Kale,_raw
#  + 0.51 x_Leaf,_amaranth,_spiney,_raw + 0.3 x_Leaf,_bitter_gourd,_raw
#  + 0.72 x_Leaf,_drumstick,_raw + 0.15 x_Leaf,_greens,_mustard
#  + 0.22 x_Leaf,_mustard_spinach,_raw + 0.29 x_Leaf,_pumpkin,_raw
#  + 0.65 x_Mango,_ripe + 0.65 x_Mango,_unripe + 0.66 x_Milk,_cow,_fresh
#  + 2.96 x_Mushrooms,_shiitake,_dried + 0.34 x_Mushrooms,_shiitake,_raw
#  + 3.84 x_Noodles,_egg,_dry,_enriched + 1.08 x_Noodles,_rice,_cooked
#  + 8.62 x_Oil,_vegetable + 0.59 x_Onion,_raw + 0.44 x_Orange
#  + 0.33 x_Papaya,_ripe + 0.22 x_Papaya,_unripe,_raw
#  + 5.67 x_Peanut,_without_shell + 0.47 x_Pineapple,_ripe
#  + 1.16 x_Plantain,_all_varieties + 2.24 x_Pork,_back_ribs,_raw
#  + 1.34 x_Pork,_liver,_raw + 2.11 x_Pork,_meat,_raw
#  + 1.16 x_Pork_or_Goat,_blood,_coagulated + 0.18 x_Pumpkin,_raw
#  + 2.08 x_Quail,_meat + 0.13 x_Radish,_chinese,_raw
#  + 3.53 x_Rice,_white,_polished,_raw + 0.79 x_Shrimp,_raw
#  + 4.24 x_Soybean,_dried,_raw + 1.47 x_Squid,_raw + 3.69 x_Sugar,_palm
#  + 3.98 x_Sugar,_white
#  + 1.04 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.98 x_Sweet_potato,_white_flesh,_raw + 0.92 x_Taro,_tuber,_raw
#  + 0.76 x_Tofu + 0.16 x_Tomato,_red,_ripe,_raw + 0.43 x_Water_spinach,_raw
#  + 0.38 x_Yam_bean,_jicama,_raw + 0.61 x_Yogurt >= 2291.25
#
# nutrient_Energy_(kcal)_upper: 0.92 x_Banana,_ripe + 0.21 x_Banana_flower_heart
#  + 3.26 x_Bean,_kidney,_dried,_raw + 1.16 x_Bean,_mung,_dry
#  + 0.47 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.61 x_Beansprout,_mung_bean,_raw + 1.45 x_Beef,_blood,_coagulated
#  + 1.3 x_Beef,_liver,_raw + 1.03 x_Beef,_meat,_lean,_boneless,_raw
#  + 7.1 x_Butter,_CotD + 0.13 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.16 x_Cabbage,_chinese,_pe_tsai,_raw + 0.15 x_Cabbage,_chinese,_raw
#  + 0.45 x_Carrot,_raw + 1.31 x_Cassava,_white + 0.25 x_Cauliflower,_raw
#  + 1.14 x_Chicken,_liver,_raw + 2.85 x_Chicken,_meat + 0.13 x_Cucumber,_raw
#  + 1.36 x_Duck,_liver,_raw + 1.3 x_Duck,_meat,_raw
#  + 1.39 x_Egg,_chicken,_farmed,_raw + 1.88 x_Egg,_duck,_whole,_raw
#  + 0.28 x_Eggplant,_purple + 0.25 x_Eggplant,_raw
#  + 2.45 x_Fish,_Snakehead,_dried
#  + 1.39 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 1.17 x_Fish,_catfish,_raw + 1.14 x_Fish,_days_mystus,_eyes_included,_raw
#  + 1.05 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.84 x_Fish,_small,_fresh,_fresh_water
#  + 1.01 x_Fish,_snakehead,_striped,_raw + 3.35 x_Fish,_tilapia,_dried
#  + 0.96 x_Fish,_tilapia,_raw + 1.05 x_Fish_paste,_red,_fermented
#  + 0.31 x_Gourd,_bitter,_raw + 0.29 x_Gourd,_ridge,_raw
#  + 0.24 x_Gourd,_sponge,_raw + 0.2 x_Gourd,_wax + 0.51 x_Guava
#  + 0.37 x_Ivygourd,_leaf,_raw + 0.74 x_Jackfruit,_ripe + 0.49 x_Kale,_raw
#  + 0.51 x_Leaf,_amaranth,_spiney,_raw + 0.3 x_Leaf,_bitter_gourd,_raw
#  + 0.72 x_Leaf,_drumstick,_raw + 0.15 x_Leaf,_greens,_mustard
#  + 0.22 x_Leaf,_mustard_spinach,_raw + 0.29 x_Leaf,_pumpkin,_raw
#  + 0.65 x_Mango,_ripe + 0.65 x_Mango,_unripe + 0.66 x_Milk,_cow,_fresh
#  + 2.96 x_Mushrooms,_shiitake,_dried + 0.34 x_Mushrooms,_shiitake,_raw
#  + 3.84 x_Noodles,_egg,_dry,_enriched + 1.08 x_Noodles,_rice,_cooked
#  + 8.62 x_Oil,_vegetable + 0.59 x_Onion,_raw + 0.44 x_Orange
#  + 0.33 x_Papaya,_ripe + 0.22 x_Papaya,_unripe,_raw
#  + 5.67 x_Peanut,_without_shell + 0.47 x_Pineapple,_ripe
#  + 1.16 x_Plantain,_all_varieties + 2.24 x_Pork,_back_ribs,_raw
#  + 1.34 x_Pork,_liver,_raw + 2.11 x_Pork,_meat,_raw
#  + 1.16 x_Pork_or_Goat,_blood,_coagulated + 0.18 x_Pumpkin,_raw
#  + 2.08 x_Quail,_meat + 0.13 x_Radish,_chinese,_raw
#  + 3.53 x_Rice,_white,_polished,_raw + 0.79 x_Shrimp,_raw
#  + 4.24 x_Soybean,_dried,_raw + 1.47 x_Squid,_raw + 3.69 x_Sugar,_palm
#  + 3.98 x_Sugar,_white
#  + 1.04 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.98 x_Sweet_potato,_white_flesh,_raw + 0.92 x_Taro,_tuber,_raw
#  + 0.76 x_Tofu + 0.16 x_Tomato,_red,_ripe,_raw + 0.43 x_Water_spinach,_raw
#  + 0.38 x_Yam_bean,_jicama,_raw + 0.61 x_Yogurt <= 2408.75
#
# nutrient_Protein_(g)_lower: 0.01 x_Banana,_ripe + 0.012 x_Banana_flower_heart
#  + 0.224 x_Bean,_kidney,_dried,_raw + 0.077 x_Bean,_mung,_dry
#  + 0.028 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.066 x_Beansprout,_mung_bean,_raw + 0.251 x_Beef,_blood,_coagulated
#  + 0.2036 x_Beef,_liver,_raw + 0.207425 x_Beef,_meat,_lean,_boneless,_raw
#  + 0.002 x_Butter,_CotD + 0.015 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.012 x_Cabbage,_chinese,_pe_tsai,_raw + 0.023 x_Cabbage,_chinese,_raw
#  + 0.011 x_Carrot,_raw + 0.011 x_Cassava,_white + 0.014 x_Cauliflower,_raw
#  + 0.1692 x_Chicken,_liver,_raw + 0.269 x_Chicken,_meat
#  + 0.007 x_Cucumber,_raw + 0.1874 x_Duck,_liver,_raw + 0.216 x_Duck,_meat,_raw
#  + 0.14489 x_Egg,_chicken,_farmed,_raw + 0.1348 x_Egg,_duck,_whole,_raw
#  + 0.008 x_Eggplant,_purple + 0.0098 x_Eggplant,_raw
#  + 0.531 x_Fish,_Snakehead,_dried
#  + 0.176 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.1633 x_Fish,_catfish,_raw
#  + 0.1818333333 x_Fish,_days_mystus,_eyes_included,_raw
#  + 0.158325 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.148 x_Fish,_small,_fresh,_fresh_water
#  + 0.177425 x_Fish,_snakehead,_striped,_raw + 0.586 x_Fish,_tilapia,_dried
#  + 0.2008 x_Fish,_tilapia,_raw + 0.185 x_Fish_paste,_red,_fermented
#  + 0.02055 x_Gourd,_bitter,_raw + 0.01275 x_Gourd,_ridge,_raw
#  + 0.0089 x_Gourd,_sponge,_raw + 0.009 x_Gourd,_wax + 0.008 x_Guava
#  + 0.036 x_Ivygourd,_leaf,_raw + 0.01195 x_Jackfruit,_ripe
#  + 0.0428 x_Kale,_raw + 0.048033 x_Leaf,_amaranth,_spiney,_raw
#  + 0.053 x_Leaf,_bitter_gourd,_raw + 0.067 x_Leaf,_drumstick,_raw
#  + 0.023 x_Leaf,_greens,_mustard + 0.022 x_Leaf,_mustard_spinach,_raw
#  + 0.02442 x_Leaf,_pumpkin,_raw + 0.005 x_Mango,_ripe + 0.005 x_Mango,_unripe
#  + 0.032 x_Milk,_cow,_fresh + 0.0958 x_Mushrooms,_shiitake,_dried
#  + 0.0224 x_Mushrooms,_shiitake,_raw + 0.1416 x_Noodles,_egg,_dry,_enriched
#  + 0.0179 x_Noodles,_rice,_cooked + 0.01375 x_Onion,_raw + 0.0068 x_Orange
#  + 0.0061 x_Papaya,_ripe + 0.01 x_Papaya,_unripe,_raw
#  + 0.258 x_Peanut,_without_shell + 0.00958 x_Pineapple,_ripe
#  + 0.008 x_Plantain,_all_varieties + 0.1907 x_Pork,_back_ribs,_raw
#  + 0.2139 x_Pork,_liver,_raw + 0.1822 x_Pork,_meat,_raw
#  + 0.201 x_Pork_or_Goat,_blood,_coagulated + 0.014 x_Pumpkin,_raw
#  + 0.281 x_Quail,_meat + 0.007 x_Radish,_chinese,_raw
#  + 0.06141215299 x_Rice,_white,_polished,_raw + 0.167 x_Shrimp,_raw
#  + 0.3293680267 x_Soybean,_dried,_raw + 0.25 x_Squid,_raw
#  + 0.006 x_Sugar,_palm
#  + 0.00635 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.00615 x_Sweet_potato,_white_flesh,_raw + 0.01701387963 x_Taro,_tuber,_raw
#  + 0.081 x_Tofu + 0.01106 x_Tomato,_red,_ripe,_raw
#  + 0.01921666667 x_Water_spinach,_raw + 0.0072 x_Yam_bean,_jicama,_raw
#  + 0.0347 x_Yogurt >= 70.5
#
# nutrient_Fat_(g)_lower: 0.005 x_Banana,_ripe + 0.007 x_Banana_flower_heart
#  + 0.013 x_Bean,_kidney,_dried,_raw + 0.005 x_Bean,_mung,_dry
#  + 0.004 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.034 x_Beansprout,_mung_bean,_raw + 0.042 x_Beef,_blood,_coagulated
#  + 0.0363 x_Beef,_liver,_raw + 0.02255 x_Beef,_meat,_lean,_boneless,_raw
#  + 0.806 x_Butter,_CotD + 0.002 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.002 x_Cabbage,_chinese,_pe_tsai,_raw + 0.002 x_Cabbage,_chinese,_raw
#  + 0.002 x_Carrot,_raw + 0.003 x_Cassava,_white + 0.003 x_Cauliflower,_raw
#  + 0.0483 x_Chicken,_liver,_raw + 0.189 x_Chicken,_meat
#  + 0.001 x_Cucumber,_raw + 0.0464 x_Duck,_liver,_raw + 0.048 x_Duck,_meat,_raw
#  + 0.09 x_Egg,_chicken,_farmed,_raw + 0.1429 x_Egg,_duck,_whole,_raw
#  + 0.002 x_Eggplant,_purple + 0.0018 x_Eggplant,_raw
#  + 0.02 x_Fish,_Snakehead,_dried
#  + 0.07645 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.057 x_Fish,_catfish,_raw
#  + 0.04564285714 x_Fish,_days_mystus,_eyes_included,_raw
#  + 0.04576666667 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.023 x_Fish,_small,_fresh,_fresh_water
#  + 0.033 x_Fish,_snakehead,_striped,_raw + 0.094 x_Fish,_tilapia,_dried
#  + 0.017 x_Fish,_tilapia,_raw + 0.029 x_Fish_paste,_red,_fermented
#  + 0.003425 x_Gourd,_bitter,_raw + 0.0035 x_Gourd,_ridge,_raw
#  + 0.0015 x_Gourd,_sponge,_raw + 0.003 x_Gourd,_wax + 0.006 x_Guava
#  + 0.002 x_Ivygourd,_leaf,_raw + 0.00204 x_Jackfruit,_ripe
#  + 0.0093 x_Kale,_raw + 0.0025 x_Leaf,_amaranth,_spiney,_raw
#  + 0.0069 x_Leaf,_bitter_gourd,_raw + 0.01799533333 x_Leaf,_drumstick,_raw
#  + 0.002 x_Leaf,_greens,_mustard + 0.003 x_Leaf,_mustard_spinach,_raw
#  + 0.0044 x_Leaf,_pumpkin,_raw + 0.003 x_Mango,_ripe + 0.003 x_Mango,_unripe
#  + 0.039 x_Milk,_cow,_fresh + 0.0099 x_Mushrooms,_shiitake,_dried
#  + 0.0049 x_Mushrooms,_shiitake,_raw + 0.0444 x_Noodles,_egg,_dry,_enriched
#  + 0.002 x_Noodles,_rice,_cooked + x_Oil,_vegetable + 0.00074 x_Onion,_raw
#  + 0.002 x_Orange + 0.00146666667 x_Papaya,_ripe + 0.004 x_Papaya,_unripe,_raw
#  + 0.492 x_Peanut,_without_shell + 0.00135 x_Pineapple,_ripe
#  + 0.002 x_Plantain,_all_varieties + 0.1633 x_Pork,_back_ribs,_raw
#  + 0.0365 x_Pork,_liver,_raw + 0.1479 x_Pork,_meat,_raw
#  + 0.034 x_Pork_or_Goat,_blood,_coagulated + 0.003 x_Pumpkin,_raw
#  + 0.097 x_Quail,_meat + 0.001 x_Radish,_chinese,_raw
#  + 0.00462644305 x_Rice,_white,_polished,_raw + 0.009 x_Shrimp,_raw
#  + 0.1994 x_Soybean,_dried,_raw + 0.022 x_Squid,_raw
#  + 0.0026 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.0026 x_Sweet_potato,_white_flesh,_raw + 0.001 x_Taro,_tuber,_raw
#  + 0.048 x_Tofu + 0.00248 x_Tomato,_red,_ripe,_raw
#  + 0.00384 x_Water_spinach,_raw + 0.0009 x_Yam_bean,_jicama,_raw
#  + 0.0325 x_Yogurt >= 52.2222222222
#
# nutrient_Fat_(g)_upper: 0.005 x_Banana,_ripe + 0.007 x_Banana_flower_heart
#  + 0.013 x_Bean,_kidney,_dried,_raw + 0.005 x_Bean,_mung,_dry
#  + 0.004 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.034 x_Beansprout,_mung_bean,_raw + 0.042 x_Beef,_blood,_coagulated
#  + 0.0363 x_Beef,_liver,_raw + 0.02255 x_Beef,_meat,_lean,_boneless,_raw
#  + 0.806 x_Butter,_CotD + 0.002 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.002 x_Cabbage,_chinese,_pe_tsai,_raw + 0.002 x_Cabbage,_chinese,_raw
#  + 0.002 x_Carrot,_raw + 0.003 x_Cassava,_white + 0.003 x_Cauliflower,_raw
#  + 0.0483 x_Chicken,_liver,_raw + 0.189 x_Chicken,_meat
#  + 0.001 x_Cucumber,_raw + 0.0464 x_Duck,_liver,_raw + 0.048 x_Duck,_meat,_raw
#  + 0.09 x_Egg,_chicken,_farmed,_raw + 0.1429 x_Egg,_duck,_whole,_raw
#  + 0.002 x_Eggplant,_purple + 0.0018 x_Eggplant,_raw
#  + 0.02 x_Fish,_Snakehead,_dried
#  + 0.07645 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.057 x_Fish,_catfish,_raw
#  + 0.04564285714 x_Fish,_days_mystus,_eyes_included,_raw
#  + 0.04576666667 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.023 x_Fish,_small,_fresh,_fresh_water
#  + 0.033 x_Fish,_snakehead,_striped,_raw + 0.094 x_Fish,_tilapia,_dried
#  + 0.017 x_Fish,_tilapia,_raw + 0.029 x_Fish_paste,_red,_fermented
#  + 0.003425 x_Gourd,_bitter,_raw + 0.0035 x_Gourd,_ridge,_raw
#  + 0.0015 x_Gourd,_sponge,_raw + 0.003 x_Gourd,_wax + 0.006 x_Guava
#  + 0.002 x_Ivygourd,_leaf,_raw + 0.00204 x_Jackfruit,_ripe
#  + 0.0093 x_Kale,_raw + 0.0025 x_Leaf,_amaranth,_spiney,_raw
#  + 0.0069 x_Leaf,_bitter_gourd,_raw + 0.01799533333 x_Leaf,_drumstick,_raw
#  + 0.002 x_Leaf,_greens,_mustard + 0.003 x_Leaf,_mustard_spinach,_raw
#  + 0.0044 x_Leaf,_pumpkin,_raw + 0.003 x_Mango,_ripe + 0.003 x_Mango,_unripe
#  + 0.039 x_Milk,_cow,_fresh + 0.0099 x_Mushrooms,_shiitake,_dried
#  + 0.0049 x_Mushrooms,_shiitake,_raw + 0.0444 x_Noodles,_egg,_dry,_enriched
#  + 0.002 x_Noodles,_rice,_cooked + x_Oil,_vegetable + 0.00074 x_Onion,_raw
#  + 0.002 x_Orange + 0.00146666667 x_Papaya,_ripe + 0.004 x_Papaya,_unripe,_raw
#  + 0.492 x_Peanut,_without_shell + 0.00135 x_Pineapple,_ripe
#  + 0.002 x_Plantain,_all_varieties + 0.1633 x_Pork,_back_ribs,_raw
#  + 0.0365 x_Pork,_liver,_raw + 0.1479 x_Pork,_meat,_raw
#  + 0.034 x_Pork_or_Goat,_blood,_coagulated + 0.003 x_Pumpkin,_raw
#  + 0.097 x_Quail,_meat + 0.001 x_Radish,_chinese,_raw
#  + 0.00462644305 x_Rice,_white,_polished,_raw + 0.009 x_Shrimp,_raw
#  + 0.1994 x_Soybean,_dried,_raw + 0.022 x_Squid,_raw
#  + 0.0026 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.0026 x_Sweet_potato,_white_flesh,_raw + 0.001 x_Taro,_tuber,_raw
#  + 0.048 x_Tofu + 0.00248 x_Tomato,_red,_ripe,_raw
#  + 0.00384 x_Water_spinach,_raw + 0.0009 x_Yam_bean,_jicama,_raw
#  + 0.0325 x_Yogurt <= 91.3888888889
#
# nutrient_Calcium_(mg)_lower: 0.06 x_Banana,_ripe + 0.2 x_Banana_flower_heart
#  + 0.72 x_Bean,_kidney,_dried,_raw + 0.24 x_Bean,_mung,_dry
#  + 0.5 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.34 x_Beansprout,_mung_bean,_raw + 0.12 x_Beef,_blood,_coagulated
#  + 0.04045 x_Beef,_liver,_raw
#  + 0.04259230769 x_Beef,_meat,_lean,_boneless,_raw + 0.06 x_Butter,_CotD
#  + 1.05 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.77 x_Cabbage,_chinese,_pe_tsai,_raw + 0.74 x_Cabbage,_chinese,_raw
#  + 0.31 x_Carrot,_raw + 0.19 x_Cassava,_white + 0.47 x_Cauliflower,_raw
#  + 0.1835 x_Chicken,_liver,_raw + 0.13 x_Chicken,_meat + 0.14 x_Cucumber,_raw
#  + 0.11 x_Duck,_liver,_raw + 0.04 x_Duck,_meat,_raw
#  + 0.65 x_Egg,_duck,_whole,_raw + 0.06 x_Eggplant,_purple
#  + 0.09 x_Eggplant,_raw + 0.33 x_Fish,_Snakehead,_dried
#  + 9.673333333 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.38 x_Fish,_catfish,_raw + 6.2725 x_Fish,_days_mystus,_eyes_included,_raw
#  + 4.216666667 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.09 x_Fish,_small,_fresh,_fresh_water
#  + 1.0382 x_Fish,_snakehead,_striped,_raw + 17 x_Fish,_tilapia,_dried
#  + 0.1 x_Fish,_tilapia,_raw + 0.12 x_Fish_paste,_red,_fermented
#  + 0.15982 x_Gourd,_bitter,_raw + 0.2073333333 x_Gourd,_ridge,_raw
#  + 0.1915 x_Gourd,_sponge,_raw + 0.27 x_Gourd,_wax + 0.2 x_Guava
#  + 0.57 x_Ivygourd,_leaf,_raw + 0.1314857143 x_Jackfruit,_ripe
#  + 1.5 x_Kale,_raw + 6.395 x_Leaf,_amaranth,_spiney,_raw
#  + 0.84 x_Leaf,_bitter_gourd,_raw + 4.4 x_Leaf,_drumstick,_raw
#  + 0.74 x_Leaf,_greens,_mustard + 2.1 x_Leaf,_mustard_spinach,_raw
#  + 0.4 x_Leaf,_pumpkin,_raw + 0.1 x_Mango,_ripe + 0.1 x_Mango,_unripe
#  + 1.15 x_Milk,_cow,_fresh + 0.11 x_Mushrooms,_shiitake,_dried
#  + 0.02 x_Mushrooms,_shiitake,_raw + 0.35 x_Noodles,_egg,_dry,_enriched
#  + 0.04 x_Noodles,_rice,_cooked + 0.23969 x_Onion,_raw + 0.23415 x_Orange
#  + 0.28682 x_Papaya,_ripe + 0.31 x_Papaya,_unripe,_raw
#  + 0.92 x_Peanut,_without_shell + 0.1788333333 x_Pineapple,_ripe
#  + 0.02 x_Plantain,_all_varieties + 0.31 x_Pork,_back_ribs,_raw
#  + 0.09 x_Pork,_liver,_raw + 0.11 x_Pork,_meat,_raw
#  + 0.1 x_Pork_or_Goat,_blood,_coagulated + 0.5182 x_Pumpkin,_raw
#  + 0.26 x_Quail,_meat + 0.14 x_Radish,_chinese,_raw
#  + 0.108381217 x_Rice,_white,_polished,_raw + 0.31 x_Shrimp,_raw
#  + 2.40565 x_Soybean,_dried,_raw + 0.51 x_Squid,_raw + 3.77 x_Sugar,_palm
#  + 0.12 x_Sugar,_white
#  + 0.32 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.245 x_Sweet_potato,_white_flesh,_raw + 0.333213 x_Taro,_tuber,_raw
#  + 1.05 x_Tofu + 0.12952 x_Tomato,_red,_ripe,_raw + 1.07 x_Water_spinach,_raw
#  + 0.12 x_Yam_bean,_jicama,_raw + 1.21 x_Yogurt >= 1000
#
# nutrient_Calcium_(mg)_upper: 0.06 x_Banana,_ripe + 0.2 x_Banana_flower_heart
#  + 0.72 x_Bean,_kidney,_dried,_raw + 0.24 x_Bean,_mung,_dry
#  + 0.5 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.34 x_Beansprout,_mung_bean,_raw + 0.12 x_Beef,_blood,_coagulated
#  + 0.04045 x_Beef,_liver,_raw
#  + 0.04259230769 x_Beef,_meat,_lean,_boneless,_raw + 0.06 x_Butter,_CotD
#  + 1.05 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.77 x_Cabbage,_chinese,_pe_tsai,_raw + 0.74 x_Cabbage,_chinese,_raw
#  + 0.31 x_Carrot,_raw + 0.19 x_Cassava,_white + 0.47 x_Cauliflower,_raw
#  + 0.1835 x_Chicken,_liver,_raw + 0.13 x_Chicken,_meat + 0.14 x_Cucumber,_raw
#  + 0.11 x_Duck,_liver,_raw + 0.04 x_Duck,_meat,_raw
#  + 0.65 x_Egg,_duck,_whole,_raw + 0.06 x_Eggplant,_purple
#  + 0.09 x_Eggplant,_raw + 0.33 x_Fish,_Snakehead,_dried
#  + 9.673333333 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.38 x_Fish,_catfish,_raw + 6.2725 x_Fish,_days_mystus,_eyes_included,_raw
#  + 4.216666667 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.09 x_Fish,_small,_fresh,_fresh_water
#  + 1.0382 x_Fish,_snakehead,_striped,_raw + 17 x_Fish,_tilapia,_dried
#  + 0.1 x_Fish,_tilapia,_raw + 0.12 x_Fish_paste,_red,_fermented
#  + 0.15982 x_Gourd,_bitter,_raw + 0.2073333333 x_Gourd,_ridge,_raw
#  + 0.1915 x_Gourd,_sponge,_raw + 0.27 x_Gourd,_wax + 0.2 x_Guava
#  + 0.57 x_Ivygourd,_leaf,_raw + 0.1314857143 x_Jackfruit,_ripe
#  + 1.5 x_Kale,_raw + 6.395 x_Leaf,_amaranth,_spiney,_raw
#  + 0.84 x_Leaf,_bitter_gourd,_raw + 4.4 x_Leaf,_drumstick,_raw
#  + 0.74 x_Leaf,_greens,_mustard + 2.1 x_Leaf,_mustard_spinach,_raw
#  + 0.4 x_Leaf,_pumpkin,_raw + 0.1 x_Mango,_ripe + 0.1 x_Mango,_unripe
#  + 1.15 x_Milk,_cow,_fresh + 0.11 x_Mushrooms,_shiitake,_dried
#  + 0.02 x_Mushrooms,_shiitake,_raw + 0.35 x_Noodles,_egg,_dry,_enriched
#  + 0.04 x_Noodles,_rice,_cooked + 0.23969 x_Onion,_raw + 0.23415 x_Orange
#  + 0.28682 x_Papaya,_ripe + 0.31 x_Papaya,_unripe,_raw
#  + 0.92 x_Peanut,_without_shell + 0.1788333333 x_Pineapple,_ripe
#  + 0.02 x_Plantain,_all_varieties + 0.31 x_Pork,_back_ribs,_raw
#  + 0.09 x_Pork,_liver,_raw + 0.11 x_Pork,_meat,_raw
#  + 0.1 x_Pork_or_Goat,_blood,_coagulated + 0.5182 x_Pumpkin,_raw
#  + 0.26 x_Quail,_meat + 0.14 x_Radish,_chinese,_raw
#  + 0.108381217 x_Rice,_white,_polished,_raw + 0.31 x_Shrimp,_raw
#  + 2.40565 x_Soybean,_dried,_raw + 0.51 x_Squid,_raw + 3.77 x_Sugar,_palm
#  + 0.12 x_Sugar,_white
#  + 0.32 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.245 x_Sweet_potato,_white_flesh,_raw + 0.333213 x_Taro,_tuber,_raw
#  + 1.05 x_Tofu + 0.12952 x_Tomato,_red,_ripe,_raw + 1.07 x_Water_spinach,_raw
#  + 0.12 x_Yam_bean,_jicama,_raw + 1.21 x_Yogurt <= 2825
#
# nutrient_Folic_acid_(µg_DFE)_lower: 0.19 x_Banana,_ripe
#  + 0.4 x_Banana_flower_heart + 3.34 x_Bean,_kidney,_dried,_raw
#  + 2.08 x_Bean,_mung,_dry + 0.62 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.86 x_Beansprout,_mung_bean,_raw + 0.04 x_Beef,_blood,_coagulated
#  + 2.9 x_Beef,_liver,_raw + 0.07 x_Beef,_meat,_lean,_boneless,_raw
#  + 0.01 x_Butter,_CotD + 0.66 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.79 x_Cabbage,_chinese,_pe_tsai,_raw + 0.73 x_Cabbage,_chinese,_raw
#  + 0.14 x_Carrot,_raw + 0.15 x_Cassava,_white + 0.43 x_Cauliflower,_raw
#  + 5.88 x_Chicken,_liver,_raw + 0.05 x_Chicken,_meat + 0.13 x_Cucumber,_raw
#  + 7.38 x_Duck,_liver,_raw + 0.25 x_Duck,_meat,_raw
#  + 0.5 x_Egg,_chicken,_farmed,_raw + 0.8 x_Egg,_duck,_whole,_raw
#  + 0.14 x_Eggplant,_purple + 0.22 x_Eggplant,_raw
#  + 0.28 x_Fish,_Snakehead,_dried + 0.08 x_Fish,_catfish,_raw
#  + 0.08 x_Fish,_small,_fresh,_fresh_water + 0.28 x_Fish,_tilapia,_dried
#  + 0.24 x_Fish,_tilapia,_raw + 0.1 x_Fish_paste,_red,_fermented
#  + 0.45 x_Gourd,_bitter,_raw + 0.07 x_Gourd,_ridge,_raw
#  + 0.07 x_Gourd,_sponge,_raw + 0.2 x_Gourd,_wax + 0.14 x_Guava
#  + 0.36 x_Ivygourd,_leaf,_raw + 0.24 x_Jackfruit,_ripe + 1.41 x_Kale,_raw
#  + 0.85 x_Leaf,_amaranth,_spiney,_raw + 1.28 x_Leaf,_bitter_gourd,_raw
#  + 2.05 x_Leaf,_drumstick,_raw + 0.73 x_Leaf,_greens,_mustard
#  + 1.59 x_Leaf,_mustard_spinach,_raw + 0.36 x_Leaf,_pumpkin,_raw
#  + 0.05 x_Mango,_ripe + 0.05 x_Mango,_unripe + 0.06 x_Milk,_cow,_fresh
#  + 1.63 x_Mushrooms,_shiitake,_dried + 0.13 x_Mushrooms,_shiitake,_raw
#  + 2.3 x_Noodles,_egg,_dry,_enriched + 0.01 x_Noodles,_rice,_cooked
#  + 0.19 x_Onion,_raw + 0.2 x_Papaya,_unripe,_raw
#  + 1.26 x_Peanut,_without_shell + 0.121 x_Pineapple,_ripe
#  + 0.26 x_Plantain,_all_varieties + 2.12 x_Pork,_liver,_raw
#  + 0.03 x_Pork,_meat,_raw + 0.03 x_Pork_or_Goat,_blood,_coagulated
#  + 0.16 x_Pumpkin,_raw + 0.07 x_Quail,_meat + 0.13 x_Radish,_chinese,_raw
#  + 0.2 x_Rice,_white,_polished,_raw + 0.03 x_Shrimp,_raw
#  + x_Soybean,_dried,_raw + 0.03 x_Squid,_raw + 0.01 x_Sugar,_palm
#  + 0.11 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.11 x_Sweet_potato,_white_flesh,_raw + 0.22 x_Taro,_tuber,_raw
#  + 0.15 x_Tofu + 0.15 x_Tomato,_red,_ripe,_raw + 0.57 x_Water_spinach,_raw
#  + 0.12 x_Yam_bean,_jicama,_raw + 0.07 x_Yogurt >= 400
#
# nutrient_Iron_absorbed_(mg)_lower: 0.00015 x_Banana,_ripe
#  + 0.00035 x_Banana_flower_heart + 0.00375 x_Bean,_kidney,_dried,_raw
#  + 0.00125 x_Bean,_mung,_dry + 0.000235 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.00055 x_Beansprout,_mung_bean,_raw + 0.0985 x_Beef,_blood,_coagulated
#  + 0.00875 x_Beef,_liver,_raw
#  + 0.00494615385 x_Beef,_meat,_lean,_boneless,_raw + 0.00025 x_Butter,_CotD
#  + 0.0004 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.000155 x_Cabbage,_chinese,_pe_tsai,_raw + 0.00055 x_Cabbage,_chinese,_raw
#  + 0.0003 x_Carrot,_raw + 0.0004 x_Cassava,_white + 0.0003 x_Cauliflower,_raw
#  + 0.022475 x_Chicken,_liver,_raw + 0.0035 x_Chicken,_meat
#  + 0.00015 x_Cucumber,_raw + 0.076325 x_Duck,_liver,_raw
#  + 0.006 x_Duck,_meat,_raw + 0.00385 x_Egg,_chicken,_farmed,_raw
#  + 0.00604918333 x_Egg,_duck,_whole,_raw + 0.0002 x_Eggplant,_purple
#  + 0.000115 x_Eggplant,_raw + 0.00275 x_Fish,_Snakehead,_dried
#  + 0.0065 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.00225 x_Fish,_catfish,_raw
#  + 0.00688 x_Fish,_days_mystus,_eyes_included,_raw
#  + 0.002275 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.00075 x_Fish,_small,_fresh,_fresh_water
#  + 0.002603125 x_Fish,_snakehead,_striped,_raw
#  + 0.00625 x_Fish,_tilapia,_dried + 0.0014 x_Fish,_tilapia,_raw
#  + 0.001 x_Fish_paste,_red,_fermented + 0.000892125 x_Gourd,_bitter,_raw
#  + 0.00062916667 x_Gourd,_ridge,_raw + 0.0003 x_Gourd,_sponge,_raw
#  + 0.0002 x_Gourd,_wax + 0.00015 x_Guava + 0.0007 x_Ivygourd,_leaf,_raw
#  + 0.00016020113 x_Jackfruit,_ripe + 0.000735 x_Kale,_raw
#  + 0.00102 x_Leaf,_bitter_gourd,_raw + 0.000425 x_Leaf,_drumstick,_raw
#  + 0.00055 x_Leaf,_greens,_mustard + 0.00075 x_Leaf,_mustard_spinach,_raw
#  + 0.00111 x_Leaf,_pumpkin,_raw + 5e-05 x_Mango,_ripe + 5e-05 x_Mango,_unripe
#  + 0.0001175 x_Milk,_cow,_fresh + 0.00086 x_Mushrooms,_shiitake,_dried
#  + 0.000205 x_Mushrooms,_shiitake,_raw
#  + 0.002005 x_Noodles,_egg,_dry,_enriched + 7e-05 x_Noodles,_rice,_cooked
#  + 0.00047080876 x_Onion,_raw + 0.00012175 x_Orange
#  + 0.0001743475 x_Papaya,_ripe + 0.0001 x_Papaya,_unripe,_raw
#  + 0.0023 x_Peanut,_without_shell + 0.0003337 x_Pineapple,_ripe
#  + 0.0003 x_Plantain,_all_varieties + 0.0019 x_Pork,_back_ribs,_raw
#  + 0.05825 x_Pork,_liver,_raw + 0.002225 x_Pork,_meat,_raw
#  + 0.07875 x_Pork_or_Goat,_blood,_coagulated + 0.00035 x_Pumpkin,_raw
#  + 0.0045 x_Quail,_meat + 0.00015 x_Radish,_chinese,_raw
#  + 0.00036509675 x_Rice,_white,_polished,_raw + 0.00625 x_Shrimp,_raw
#  + 0.00567 x_Soybean,_dried,_raw + 0.00275 x_Squid,_raw + 0.0009 x_Sugar,_palm
#  + 8e-05 x_Sugar,_white
#  + 0.00072045 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.0007575 x_Sweet_potato,_white_flesh,_raw + 0.00045 x_Taro,_tuber,_raw
#  + 0.0027 x_Tofu + 9.860539e-05 x_Tomato,_red,_ripe,_raw
#  + 0.00109879833 x_Water_spinach,_raw + 0.0003 x_Yam_bean,_jicama,_raw
#  + 5.875e-05 x_Yogurt >= 2.94
#
# nutrient_Iron_(mg)_upper: 0.003 x_Banana,_ripe + 0.007 x_Banana_flower_heart
#  + 0.075 x_Bean,_kidney,_dried,_raw + 0.025 x_Bean,_mung,_dry
#  + 0.0047 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.011 x_Beansprout,_mung_bean,_raw + 0.394 x_Beef,_blood,_coagulated
#  + 0.035 x_Beef,_liver,_raw + 0.01978461538 x_Beef,_meat,_lean,_boneless,_raw
#  + 0.001 x_Butter,_CotD + 0.008 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.0031 x_Cabbage,_chinese,_pe_tsai,_raw + 0.011 x_Cabbage,_chinese,_raw
#  + 0.006 x_Carrot,_raw + 0.008 x_Cassava,_white + 0.006 x_Cauliflower,_raw
#  + 0.0899 x_Chicken,_liver,_raw + 0.014 x_Chicken,_meat
#  + 0.003 x_Cucumber,_raw + 0.3053 x_Duck,_liver,_raw + 0.024 x_Duck,_meat,_raw
#  + 0.0154 x_Egg,_chicken,_farmed,_raw + 0.02419673333 x_Egg,_duck,_whole,_raw
#  + 0.004 x_Eggplant,_purple + 0.0023 x_Eggplant,_raw
#  + 0.011 x_Fish,_Snakehead,_dried
#  + 0.026 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.009 x_Fish,_catfish,_raw
#  + 0.02752 x_Fish,_days_mystus,_eyes_included,_raw
#  + 0.0091 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.003 x_Fish,_small,_fresh,_fresh_water
#  + 0.0104125 x_Fish,_snakehead,_striped,_raw + 0.025 x_Fish,_tilapia,_dried
#  + 0.0056 x_Fish,_tilapia,_raw + 0.004 x_Fish_paste,_red,_fermented
#  + 0.0178425 x_Gourd,_bitter,_raw + 0.01258333333 x_Gourd,_ridge,_raw
#  + 0.006 x_Gourd,_sponge,_raw + 0.004 x_Gourd,_wax + 0.003 x_Guava
#  + 0.014 x_Ivygourd,_leaf,_raw + 0.0032040227 x_Jackfruit,_ripe
#  + 0.0147 x_Kale,_raw + 0.0204 x_Leaf,_bitter_gourd,_raw
#  + 0.0085 x_Leaf,_drumstick,_raw + 0.011 x_Leaf,_greens,_mustard
#  + 0.015 x_Leaf,_mustard_spinach,_raw + 0.0222 x_Leaf,_pumpkin,_raw
#  + 0.001 x_Mango,_ripe + 0.001 x_Mango,_unripe + 0.001 x_Milk,_cow,_fresh
#  + 0.0172 x_Mushrooms,_shiitake,_dried + 0.0041 x_Mushrooms,_shiitake,_raw
#  + 0.0401 x_Noodles,_egg,_dry,_enriched + 0.0014 x_Noodles,_rice,_cooked
#  + 0.00941617526 x_Onion,_raw + 0.002435 x_Orange + 0.00348695 x_Papaya,_ripe
#  + 0.002 x_Papaya,_unripe,_raw + 0.046 x_Peanut,_without_shell
#  + 0.006674 x_Pineapple,_ripe + 0.006 x_Plantain,_all_varieties
#  + 0.0076 x_Pork,_back_ribs,_raw + 0.233 x_Pork,_liver,_raw
#  + 0.0089 x_Pork,_meat,_raw + 0.315 x_Pork_or_Goat,_blood,_coagulated
#  + 0.007 x_Pumpkin,_raw + 0.018 x_Quail,_meat + 0.003 x_Radish,_chinese,_raw
#  + 0.00730193501 x_Rice,_white,_polished,_raw + 0.025 x_Shrimp,_raw
#  + 0.1134 x_Soybean,_dried,_raw + 0.011 x_Squid,_raw + 0.018 x_Sugar,_palm
#  + 0.0016 x_Sugar,_white
#  + 0.014409 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.01515 x_Sweet_potato,_white_flesh,_raw + 0.009 x_Taro,_tuber,_raw
#  + 0.054 x_Tofu + 0.00197210789 x_Tomato,_red,_ripe,_raw
#  + 0.02197596667 x_Water_spinach,_raw + 0.006 x_Yam_bean,_jicama,_raw
#  + 0.0005 x_Yogurt <= 120
#
# nutrient_Magnesium_(mg)_lower: 0.29 x_Banana,_ripe
#  + 0.02 x_Banana_flower_heart + 1.16 x_Bean,_kidney,_dried,_raw
#  + 0.53 x_Bean,_mung,_dry + 0.44 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.36 x_Beansprout,_mung_bean,_raw + 0.19 x_Beef,_blood,_coagulated
#  + 0.18 x_Beef,_liver,_raw + 0.1531 x_Beef,_meat,_lean,_boneless,_raw
#  + 0.01 x_Butter,_CotD + 0.19 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.13 x_Cabbage,_chinese,_pe_tsai,_raw + 0.15 x_Cabbage,_chinese,_raw
#  + 0.13 x_Carrot,_raw + 0.1 x_Cassava,_white + 0.15 x_Cauliflower,_raw
#  + 0.19 x_Chicken,_liver,_raw + 0.2 x_Chicken,_meat + 0.11 x_Cucumber,_raw
#  + 0.24 x_Duck,_liver,_raw + 0.19 x_Duck,_meat,_raw
#  + 0.2088 x_Egg,_chicken,_farmed,_raw + 0.1066 x_Egg,_duck,_whole,_raw
#  + 0.13 x_Eggplant,_purple + 0.14 x_Eggplant,_raw
#  + 0.98 x_Fish,_Snakehead,_dried + 0.3 x_Fish,_catfish,_raw
#  + 0.2209 x_Fish,_days_mystus,_eyes_included,_raw
#  + 0.3580932491 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.22 x_Fish,_small,_fresh,_fresh_water
#  + 0.4265 x_Fish,_snakehead,_striped,_raw + 1.4 x_Fish,_tilapia,_dried
#  + 0.27 x_Fish,_tilapia,_raw + 0.28 x_Fish_paste,_red,_fermented
#  + 0.3125 x_Gourd,_bitter,_raw + 0.14 x_Gourd,_ridge,_raw
#  + 0.14 x_Gourd,_sponge,_raw + 0.24 x_Gourd,_wax + 0.1 x_Guava
#  + 0.68695 x_Ivygourd,_leaf,_raw + 0.42423 x_Jackfruit,_ripe
#  + 0.47 x_Kale,_raw + 0.85 x_Leaf,_bitter_gourd,_raw
#  + 0.42 x_Leaf,_drumstick,_raw + 0.15 x_Leaf,_greens,_mustard
#  + 0.11 x_Leaf,_mustard_spinach,_raw + 0.38 x_Leaf,_pumpkin,_raw
#  + 0.09 x_Mango,_ripe + 0.09 x_Mango,_unripe + 0.11 x_Milk,_cow,_fresh
#  + 1.32 x_Mushrooms,_shiitake,_dried + 0.2 x_Mushrooms,_shiitake,_raw
#  + 0.58 x_Noodles,_egg,_dry,_enriched + 0.03 x_Noodles,_rice,_cooked
#  + 0.24121 x_Onion,_raw + 0.17 x_Orange + 0.1031 x_Papaya,_ripe
#  + 0.08 x_Papaya,_unripe,_raw + 1.68 x_Peanut,_without_shell
#  + 0.3153333333 x_Pineapple,_ripe + 0.32 x_Plantain,_all_varieties
#  + 0.16 x_Pork,_back_ribs,_raw + 0.18 x_Pork,_liver,_raw
#  + 0.21 x_Pork,_meat,_raw + 0.15 x_Pork_or_Goat,_blood,_coagulated
#  + 0.1 x_Pumpkin,_raw + 0.25 x_Quail,_meat + 0.11 x_Radish,_chinese,_raw
#  + 0.35 x_Rice,_white,_polished,_raw + 0.27 x_Shrimp,_raw
#  + 2.07 x_Soybean,_dried,_raw + 0.53 x_Squid,_raw + 0.22 x_Sugar,_palm
#  + 0.02 x_Sugar,_white
#  + 0.27 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.25 x_Sweet_potato,_white_flesh,_raw + 0.2201875926 x_Taro,_tuber,_raw
#  + 1.03 x_Tofu + 0.07418 x_Tomato,_red,_ripe,_raw
#  + 0.1942 x_Water_spinach,_raw + 0.12 x_Yam_bean,_jicama,_raw + 0.12 x_Yogurt
#  >= 220
#
# nutrient_Niacin_(mg_NE)_lower: 0.007 x_Banana,_ripe
#  + 0.0055 x_Banana_flower_heart + 0.05916666667 x_Bean,_kidney,_dried,_raw
#  + 0.02083333333 x_Bean,_mung,_dry
#  + 0.0041 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.01933333333 x_Beansprout,_mung_bean,_raw
#  + 0.0995 x_Beef,_blood,_coagulated + 0.1003 x_Beef,_liver,_raw
#  + 0.0927 x_Beef,_meat,_lean,_boneless,_raw + 0.0005 x_Butter,_CotD
#  + 0.005 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.004 x_Cabbage,_chinese,_pe_tsai,_raw
#  + 0.00816666667 x_Cabbage,_chinese,_raw + 0.007 x_Carrot,_raw
#  + 0.0085 x_Cassava,_white + 0.0055 x_Cauliflower,_raw
#  + 0.0877 x_Chicken,_liver,_raw + 0.1081666667 x_Chicken,_meat
#  + 0.00283333333 x_Cucumber,_raw + 0.065 x_Duck,_liver,_raw
#  + 0.012 x_Duck,_meat,_raw + 0.034 x_Egg,_chicken,_farmed,_raw
#  + 0.045 x_Egg,_duck,_whole,_raw + 0.00733333333 x_Eggplant,_purple
#  + 0.00649 x_Eggplant,_raw + 0.1573333333 x_Fish,_Snakehead,_dried
#  + 0.003 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.014 x_Fish,_catfish,_raw
#  + 0.01954014403 x_Fish,_days_mystus,_eyes_included,_raw
#  + 0.05558423326 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.04666666667 x_Fish,_small,_fresh,_fresh_water
#  + 0.08026843833 x_Fish,_snakehead,_striped,_raw
#  + 0.1913333333 x_Fish,_tilapia,_dried + 0.03903 x_Fish,_tilapia,_raw
#  + 0.0585 x_Fish_paste,_red,_fermented + 0.007 x_Gourd,_bitter,_raw
#  + 0.005 x_Gourd,_ridge,_raw + 0.002 x_Gourd,_sponge,_raw
#  + 0.00633333333 x_Gourd,_wax + 0.01316666667 x_Guava
#  + 0.19 x_Ivygourd,_leaf,_raw + 0.0092 x_Jackfruit,_ripe + 0.01 x_Kale,_raw
#  + 0.016 x_Leaf,_amaranth,_spiney,_raw + 0.0111 x_Leaf,_bitter_gourd,_raw
#  + 0.026 x_Leaf,_drumstick,_raw + 0.00816666667 x_Leaf,_greens,_mustard
#  + 0.00678 x_Leaf,_mustard_spinach,_raw + 0.01453333333 x_Leaf,_pumpkin,_raw
#  + 0.00733333333 x_Mango,_ripe + 0.00733333333 x_Mango,_unripe
#  + 0.00866666667 x_Milk,_cow,_fresh + 0.141 x_Mushrooms,_shiitake,_dried
#  + 0.03877 x_Mushrooms,_shiitake,_raw + 0.08387 x_Noodles,_egg,_dry,_enriched
#  + 0.00072 x_Noodles,_rice,_cooked + 0.00346 x_Onion,_raw + 0.005 x_Orange
#  + 0.00488 x_Papaya,_ripe + 0.00466666667 x_Papaya,_unripe,_raw
#  + 0.1846666667 x_Peanut,_without_shell + 0.004 x_Pineapple,_ripe
#  + 0.0095 x_Plantain,_all_varieties + 0.06776 x_Pork,_back_ribs,_raw
#  + 0.15301 x_Pork,_liver,_raw + 0.0473 x_Pork,_meat,_raw
#  + 0.07983333333 x_Pork_or_Goat,_blood,_coagulated + 0.008 x_Pumpkin,_raw
#  + 0.1028333333 x_Quail,_meat + 0.00283333333 x_Radish,_chinese,_raw
#  + 0.004231056 x_Rice,_white,_polished,_raw + 0.05983333333 x_Shrimp,_raw
#  + 0.079 x_Soybean,_dried,_raw + 0.07933333333 x_Squid,_raw
#  + 0.002 x_Sugar,_palm
#  + 0.008 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.008 x_Sweet_potato,_white_flesh,_raw + 0.008 x_Taro,_tuber,_raw
#  + 0.023 x_Tofu + 0.006 x_Tomato,_red,_ripe,_raw + 0.009 x_Water_spinach,_raw
#  + 0.002 x_Yam_bean,_jicama,_raw + 0.00075 x_Yogurt >= 14
#
# nutrient_Niacin_(mg_NE)_upper: 0.007 x_Banana,_ripe
#  + 0.0055 x_Banana_flower_heart + 0.05916666667 x_Bean,_kidney,_dried,_raw
#  + 0.02083333333 x_Bean,_mung,_dry
#  + 0.0041 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.01933333333 x_Beansprout,_mung_bean,_raw
#  + 0.0995 x_Beef,_blood,_coagulated + 0.1003 x_Beef,_liver,_raw
#  + 0.0927 x_Beef,_meat,_lean,_boneless,_raw + 0.0005 x_Butter,_CotD
#  + 0.005 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.004 x_Cabbage,_chinese,_pe_tsai,_raw
#  + 0.00816666667 x_Cabbage,_chinese,_raw + 0.007 x_Carrot,_raw
#  + 0.0085 x_Cassava,_white + 0.0055 x_Cauliflower,_raw
#  + 0.0877 x_Chicken,_liver,_raw + 0.1081666667 x_Chicken,_meat
#  + 0.00283333333 x_Cucumber,_raw + 0.065 x_Duck,_liver,_raw
#  + 0.012 x_Duck,_meat,_raw + 0.034 x_Egg,_chicken,_farmed,_raw
#  + 0.045 x_Egg,_duck,_whole,_raw + 0.00733333333 x_Eggplant,_purple
#  + 0.00649 x_Eggplant,_raw + 0.1573333333 x_Fish,_Snakehead,_dried
#  + 0.003 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.014 x_Fish,_catfish,_raw
#  + 0.01954014403 x_Fish,_days_mystus,_eyes_included,_raw
#  + 0.05558423326 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.04666666667 x_Fish,_small,_fresh,_fresh_water
#  + 0.08026843833 x_Fish,_snakehead,_striped,_raw
#  + 0.1913333333 x_Fish,_tilapia,_dried + 0.03903 x_Fish,_tilapia,_raw
#  + 0.0585 x_Fish_paste,_red,_fermented + 0.007 x_Gourd,_bitter,_raw
#  + 0.005 x_Gourd,_ridge,_raw + 0.002 x_Gourd,_sponge,_raw
#  + 0.00633333333 x_Gourd,_wax + 0.01316666667 x_Guava
#  + 0.19 x_Ivygourd,_leaf,_raw + 0.0092 x_Jackfruit,_ripe + 0.01 x_Kale,_raw
#  + 0.016 x_Leaf,_amaranth,_spiney,_raw + 0.0111 x_Leaf,_bitter_gourd,_raw
#  + 0.026 x_Leaf,_drumstick,_raw + 0.00816666667 x_Leaf,_greens,_mustard
#  + 0.00678 x_Leaf,_mustard_spinach,_raw + 0.01453333333 x_Leaf,_pumpkin,_raw
#  + 0.00733333333 x_Mango,_ripe + 0.00733333333 x_Mango,_unripe
#  + 0.00866666667 x_Milk,_cow,_fresh + 0.141 x_Mushrooms,_shiitake,_dried
#  + 0.03877 x_Mushrooms,_shiitake,_raw + 0.08387 x_Noodles,_egg,_dry,_enriched
#  + 0.00072 x_Noodles,_rice,_cooked + 0.00346 x_Onion,_raw + 0.005 x_Orange
#  + 0.00488 x_Papaya,_ripe + 0.00466666667 x_Papaya,_unripe,_raw
#  + 0.1846666667 x_Peanut,_without_shell + 0.004 x_Pineapple,_ripe
#  + 0.0095 x_Plantain,_all_varieties + 0.06776 x_Pork,_back_ribs,_raw
#  + 0.15301 x_Pork,_liver,_raw + 0.0473 x_Pork,_meat,_raw
#  + 0.07983333333 x_Pork_or_Goat,_blood,_coagulated + 0.008 x_Pumpkin,_raw
#  + 0.1028333333 x_Quail,_meat + 0.00283333333 x_Radish,_chinese,_raw
#  + 0.004231056 x_Rice,_white,_polished,_raw + 0.05983333333 x_Shrimp,_raw
#  + 0.079 x_Soybean,_dried,_raw + 0.07933333333 x_Squid,_raw
#  + 0.002 x_Sugar,_palm
#  + 0.008 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.008 x_Sweet_potato,_white_flesh,_raw + 0.008 x_Taro,_tuber,_raw
#  + 0.023 x_Tofu + 0.006 x_Tomato,_red,_ripe,_raw + 0.009 x_Water_spinach,_raw
#  + 0.002 x_Yam_bean,_jicama,_raw + 0.00075 x_Yogurt <= 848
#
# nutrient_Pantothenic_acid_(mg)_lower: 0.0026 x_Banana,_ripe
#  + 0.001 x_Banana_flower_heart + 0.0057 x_Bean,_kidney,_dried,_raw
#  + 0.0041 x_Bean,_mung,_dry + 0.00055 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.0047 x_Beansprout,_mung_bean,_raw + 0.0088 x_Beef,_blood,_coagulated
#  + 0.01844013793 x_Beef,_liver,_raw
#  + 0.00551861789 x_Beef,_meat,_lean,_boneless,_raw + 0.0003 x_Butter,_CotD
#  + 0.00088 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.00105 x_Cabbage,_chinese,_pe_tsai,_raw + 0.0002 x_Cabbage,_chinese,_raw
#  + 0.003 x_Carrot,_raw + 0.0029 x_Cassava,_white + 0.0014 x_Cauliflower,_raw
#  + 0.01844013793 x_Chicken,_liver,_raw + 0.0075 x_Chicken,_meat
#  + 0.0018 x_Cucumber,_raw + 0.06184 x_Duck,_liver,_raw
#  + 0.00747391753 x_Duck,_meat,_raw + 0.01396454545 x_Egg,_chicken,_farmed,_raw
#  + 0.01396454545 x_Egg,_duck,_whole,_raw + 0.0008 x_Eggplant,_purple
#  + 0.00281 x_Eggplant,_raw + 0.0038 x_Fish,_Snakehead,_dried
#  + 0.00602327623 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.00602327623 x_Fish,_catfish,_raw
#  + 0.00602327623 x_Fish,_days_mystus,_eyes_included,_raw
#  + 0.00602327623 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.0073 x_Fish,_small,_fresh,_fresh_water
#  + 0.00602327623 x_Fish,_snakehead,_striped,_raw
#  + 0.0154 x_Fish,_tilapia,_dried + 0.00487 x_Fish,_tilapia,_raw
#  + 0.0091 x_Fish_paste,_red,_fermented + 0.00445144547 x_Gourd,_bitter,_raw
#  + 0.00445144547 x_Gourd,_ridge,_raw + 0.00445144547 x_Gourd,_sponge,_raw
#  + 0.0014 x_Gourd,_wax + 0.0015 x_Guava + 0.0016225 x_Ivygourd,_leaf,_raw
#  + 0.00178480929 x_Jackfruit,_ripe + 0.00091 x_Kale,_raw
#  + 0.00162249625 x_Leaf,_amaranth,_spiney,_raw
#  + 0.00063 x_Leaf,_bitter_gourd,_raw + 0.00162249625 x_Leaf,_drumstick,_raw
#  + 0.0002 x_Leaf,_greens,_mustard + 0.00178 x_Leaf,_mustard_spinach,_raw
#  + 0.00162249625 x_Leaf,_pumpkin,_raw + 0.0016 x_Mango,_ripe
#  + 0.0016 x_Mango,_unripe + 0.0035 x_Milk,_cow,_fresh
#  + 0.21879 x_Mushrooms,_shiitake,_dried + 0.015 x_Mushrooms,_shiitake,_raw
#  + 0.00912 x_Noodles,_egg,_dry,_enriched + 0.00011 x_Noodles,_rice,_cooked
#  + 0.00445144547 x_Onion,_raw + 0.00178480929 x_Orange
#  + 0.00178480929 x_Papaya,_ripe + 0.0014 x_Papaya,_unripe,_raw
#  + 0.0139 x_Peanut,_without_shell + 0.00178480929 x_Pineapple,_ripe
#  + 0.0023 x_Plantain,_all_varieties + 0.00818 x_Pork,_back_ribs,_raw
#  + 0.0665 x_Pork,_liver,_raw + 0.00899 x_Pork,_meat,_raw
#  + 0.007 x_Pork_or_Goat,_blood,_coagulated + 0.00288537415 x_Pumpkin,_raw
#  + 0.0086 x_Quail,_meat + 0.0018 x_Radish,_chinese,_raw
#  + 0.01080266304 x_Rice,_white,_polished,_raw + 0.008 x_Shrimp,_raw
#  + 0.00502999008 x_Soybean,_dried,_raw + 0.0032 x_Squid,_raw
#  + 0.0011 x_Sugar,_palm + 0.00321084337 x_Sugar,_white
#  + 0.00370597953 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.00370597953 x_Sweet_potato,_white_flesh,_raw
#  + 0.00370597953 x_Taro,_tuber,_raw + 0.0007 x_Tofu
#  + 0.00445144547 x_Tomato,_red,_ripe,_raw + 0.00162249625 x_Water_spinach,_raw
#  + 0.00135 x_Yam_bean,_jicama,_raw + 0.00389 x_Yogurt >= 5
#
# nutrient_Vitamin_A_(μg_RAE)_lower: 0.04 x_Banana,_ripe
#  + 0.48 x_Banana_flower_heart + 0.01 x_Bean,_mung,_dry
#  + 0.43 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.005 x_Beansprout,_mung_bean,_raw + 49.68333333 x_Beef,_liver,_raw
#  + 7.49 x_Butter,_CotD + 2.23 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.16 x_Cabbage,_chinese,_pe_tsai,_raw + 1.515 x_Cabbage,_chinese,_raw
#  + 9.71 x_Carrot,_raw + 0.03 x_Cassava,_white + 0.065 x_Cauliflower,_raw
#  + 32.95583333 x_Chicken,_liver,_raw + 0.39 x_Chicken,_meat
#  + 0.105 x_Cucumber,_raw + 119.84 x_Duck,_liver,_raw + 0.24 x_Duck,_meat,_raw
#  + 1.65246 x_Egg,_chicken,_farmed,_raw + 3.617296054 x_Egg,_duck,_whole,_raw
#  + 0.03 x_Eggplant,_purple + 0.01 x_Eggplant,_raw
#  + 0.5907052083 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.25 x_Fish,_catfish,_raw
#  + 0.4332987452 x_Fish,_days_mystus,_eyes_included,_raw
#  + 0.3866666667 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.12 x_Fish,_small,_fresh,_fresh_water + 0.15 x_Fish_paste,_red,_fermented
#  + 0.2378888889 x_Gourd,_bitter,_raw + 0.02166666667 x_Gourd,_ridge,_raw
#  + 0.145 x_Gourd,_wax + 0.395 x_Guava + 3.36 x_Ivygourd,_leaf,_raw
#  + 0.02 x_Jackfruit,_ripe + 5 x_Kale,_raw + 9.08 x_Leaf,_amaranth,_spiney,_raw
#  + 0.87 x_Leaf,_bitter_gourd,_raw + 11 x_Leaf,_drumstick,_raw
#  + 1.515 x_Leaf,_greens,_mustard + 4.95 x_Leaf,_mustard_spinach,_raw
#  + 1.616666667 x_Leaf,_pumpkin,_raw + 0.05 x_Mango,_ripe
#  + 0.05 x_Mango,_unripe + 0.55 x_Milk,_cow,_fresh
#  + 0.17 x_Noodles,_egg,_dry,_enriched + 0.01898 x_Onion,_raw
#  + 0.1868055556 x_Orange + 0.6010583333 x_Papaya,_ripe
#  + 0.065 x_Papaya,_unripe,_raw + 0.05091666667 x_Pineapple,_ripe
#  + 0.455 x_Plantain,_all_varieties + 0.07 x_Pork,_back_ribs,_raw
#  + 65.02 x_Pork,_liver,_raw + 0.01 x_Pork,_meat,_raw
#  + 3.691666667 x_Pumpkin,_raw + 0.105 x_Radish,_chinese,_raw
#  + 0.51 x_Shrimp,_raw + 0.01083333333 x_Soybean,_dried,_raw
#  + 0.08 x_Squid,_raw
#  + 0.0325 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + 0.01416666667 x_Sweet_potato,_white_flesh,_raw + 0.01875 x_Taro,_tuber,_raw
#  + 0.08654416667 x_Tomato,_red,_ripe,_raw + 1.9864 x_Water_spinach,_raw
#  + 0.01 x_Yam_bean,_jicama,_raw + 0.27 x_Yogurt >= 500
#
# nutrient_Vitamin_A_(μg_RAE)_upper: 0.04 x_Banana,_ripe
#  + 0.48 x_Banana_flower_heart + 0.01 x_Bean,_mung,_dry
#  + 0.43 x_Bean,_yard_long_bean,_immature,_raw
#  + 0.005 x_Beansprout,_mung_bean,_raw + 49.68333333 x_Beef,_liver,_raw
#  + 7.49 x_Butter,_CotD + 2.23 x_Cabbage,_chinese,_pak_choi,_raw
#  + 0.16 x_Cabbage,_chinese,_pe_tsai,_raw + 1.515 x_Cabbage,_chinese,_raw
#  + 9.71 x_Carrot,_raw + 0.03 x_Cassava,_white + 0.065 x_Cauliflower,_raw
#  + 32.95583333 x_Chicken,_liver,_raw + 0.39 x_Chicken,_meat
#  + 0.105 x_Cucumber,_raw + 119.84 x_Duck,_liver,_raw + 0.24 x_Duck,_meat,_raw
#  + 1.65246 x_Egg,_chicken,_farmed,_raw + 3.617296054 x_Egg,_duck,_whole,_raw
#  + 0.03 x_Eggplant,_purple + 0.01 x_Eggplant,_raw
#  + 0.5907052083 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  + 0.25 x_Fish,_catfish,_raw
#  + 0.4332987452 x_Fish,_days_mystus,_eyes_included,_raw
#  + 0.3866666667 x_Fish,_gouramy,_eyes_included,_raw
#  + 0.12 x_Fish,_small,_fresh,_fresh_water + 0.15 x_Fish_paste,_red,_fermented
#  + 0.2378888889 x_Gourd,_bitter,_raw + 0.02166666667 x_Gourd,_ridge,_raw
#  + 0.145 x_Gourd,_wax + 0.395 x_Guava + 3.36 x_Ivygourd,_leaf,_raw
# ...
#  - 45.5715 x_Sugar,_palm - 49.153 x_Sugar,_white
#  - 12.844 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  - 12.103 x_Sweet_potato,_white_flesh,_raw - 11.362 x_Taro,_tuber,_raw
#  + 66.614 x_Tofu - 1.976 x_Tomato,_red,_ripe,_raw
#  - 5.3105 x_Water_spinach,_raw - 4.693 x_Yam_bean,_jicama,_raw
#  - 7.5335 x_Yogurt >= 0
#
# food_group_Oils_&_fats_upper: - 10.488 x_Banana,_ripe
#  - 2.394 x_Banana_flower_heart - 37.164 x_Bean,_kidney,_dried,_raw
#  - 13.224 x_Bean,_mung,_dry - 5.358 x_Bean,_yard_long_bean,_immature,_raw
#  - 6.954 x_Beansprout,_mung_bean,_raw - 16.53 x_Beef,_blood,_coagulated
#  - 14.82 x_Beef,_liver,_raw - 11.742 x_Beef,_meat,_lean,_boneless,_raw
#  + 629.06 x_Butter,_CotD - 1.482 x_Cabbage,_chinese,_pak_choi,_raw
#  - 1.824 x_Cabbage,_chinese,_pe_tsai,_raw - 1.71 x_Cabbage,_chinese,_raw
#  - 5.13 x_Carrot,_raw - 14.934 x_Cassava,_white - 2.85 x_Cauliflower,_raw
#  - 12.996 x_Chicken,_liver,_raw - 32.49 x_Chicken,_meat
#  - 1.482 x_Cucumber,_raw - 15.504 x_Duck,_liver,_raw - 14.82 x_Duck,_meat,_raw
#  - 15.846 x_Egg,_chicken,_farmed,_raw - 21.432 x_Egg,_duck,_whole,_raw
#  - 3.192 x_Eggplant,_purple - 2.85 x_Eggplant,_raw
#  - 27.93 x_Fish,_Snakehead,_dried
#  - 15.846 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  - 13.338 x_Fish,_catfish,_raw
#  - 12.996 x_Fish,_days_mystus,_eyes_included,_raw
#  - 11.97 x_Fish,_gouramy,_eyes_included,_raw
#  - 9.576 x_Fish,_small,_fresh,_fresh_water
#  - 11.514 x_Fish,_snakehead,_striped,_raw - 38.19 x_Fish,_tilapia,_dried
#  - 10.944 x_Fish,_tilapia,_raw - 11.97 x_Fish_paste,_red,_fermented
#  - 3.534 x_Gourd,_bitter,_raw - 3.306 x_Gourd,_ridge,_raw
#  - 2.736 x_Gourd,_sponge,_raw - 2.28 x_Gourd,_wax - 5.814 x_Guava
#  - 4.218 x_Ivygourd,_leaf,_raw - 8.436 x_Jackfruit,_ripe - 5.586 x_Kale,_raw
#  - 5.814 x_Leaf,_amaranth,_spiney,_raw - 3.42 x_Leaf,_bitter_gourd,_raw
#  - 8.208 x_Leaf,_drumstick,_raw - 1.71 x_Leaf,_greens,_mustard
#  - 2.508 x_Leaf,_mustard_spinach,_raw - 3.306 x_Leaf,_pumpkin,_raw
#  - 7.41 x_Mango,_ripe - 7.41 x_Mango,_unripe - 7.524 x_Milk,_cow,_fresh
#  - 33.744 x_Mushrooms,_shiitake,_dried - 3.876 x_Mushrooms,_shiitake,_raw
#  - 43.776 x_Noodles,_egg,_dry,_enriched - 12.312 x_Noodles,_rice,_cooked
#  + 763.732 x_Oil,_vegetable - 6.726 x_Onion,_raw - 5.016 x_Orange
#  - 3.762 x_Papaya,_ripe - 2.508 x_Papaya,_unripe,_raw
#  - 64.638 x_Peanut,_without_shell - 5.358 x_Pineapple,_ripe
#  - 13.224 x_Plantain,_all_varieties - 25.536 x_Pork,_back_ribs,_raw
#  - 15.276 x_Pork,_liver,_raw - 24.054 x_Pork,_meat,_raw
#  - 13.224 x_Pork_or_Goat,_blood,_coagulated - 2.052 x_Pumpkin,_raw
#  - 23.712 x_Quail,_meat - 1.482 x_Radish,_chinese,_raw
#  - 40.242 x_Rice,_white,_polished,_raw - 9.006 x_Shrimp,_raw
#  - 48.336 x_Soybean,_dried,_raw - 16.758 x_Squid,_raw - 42.066 x_Sugar,_palm
#  - 45.372 x_Sugar,_white
#  - 11.856 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  - 11.172 x_Sweet_potato,_white_flesh,_raw - 10.488 x_Taro,_tuber,_raw
#  - 8.664 x_Tofu - 1.824 x_Tomato,_red,_ripe,_raw - 4.902 x_Water_spinach,_raw
#  - 4.332 x_Yam_bean,_jicama,_raw - 6.954 x_Yogurt >= 0
#
# food_group_Sugars_lower: - 4.6 x_Banana,_ripe - 1.05 x_Banana_flower_heart
#  - 16.3 x_Bean,_kidney,_dried,_raw - 5.8 x_Bean,_mung,_dry
#  - 2.35 x_Bean,_yard_long_bean,_immature,_raw
#  - 3.05 x_Beansprout,_mung_bean,_raw - 7.25 x_Beef,_blood,_coagulated
#  - 6.5 x_Beef,_liver,_raw - 5.15 x_Beef,_meat,_lean,_boneless,_raw
#  - 35.5 x_Butter,_CotD - 0.65 x_Cabbage,_chinese,_pak_choi,_raw
#  - 0.8 x_Cabbage,_chinese,_pe_tsai,_raw - 0.75 x_Cabbage,_chinese,_raw
#  - 2.25 x_Carrot,_raw - 6.55 x_Cassava,_white - 1.25 x_Cauliflower,_raw
#  - 5.7 x_Chicken,_liver,_raw - 14.25 x_Chicken,_meat - 0.65 x_Cucumber,_raw
#  - 6.8 x_Duck,_liver,_raw - 6.5 x_Duck,_meat,_raw
#  - 6.95 x_Egg,_chicken,_farmed,_raw - 9.4 x_Egg,_duck,_whole,_raw
#  - 1.4 x_Eggplant,_purple - 1.25 x_Eggplant,_raw
#  - 12.25 x_Fish,_Snakehead,_dried
#  - 6.95 x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw
#  - 5.85 x_Fish,_catfish,_raw - 5.7 x_Fish,_days_mystus,_eyes_included,_raw
#  - 5.25 x_Fish,_gouramy,_eyes_included,_raw
#  - 4.2 x_Fish,_small,_fresh,_fresh_water
#  - 5.05 x_Fish,_snakehead,_striped,_raw - 16.75 x_Fish,_tilapia,_dried
#  - 4.8 x_Fish,_tilapia,_raw - 5.25 x_Fish_paste,_red,_fermented
#  - 1.55 x_Gourd,_bitter,_raw - 1.45 x_Gourd,_ridge,_raw
#  - 1.2 x_Gourd,_sponge,_raw - x_Gourd,_wax - 2.55 x_Guava
#  - 1.85 x_Ivygourd,_leaf,_raw - 3.7 x_Jackfruit,_ripe - 2.45 x_Kale,_raw
#  - 2.55 x_Leaf,_amaranth,_spiney,_raw - 1.5 x_Leaf,_bitter_gourd,_raw
#  - 3.6 x_Leaf,_drumstick,_raw - 0.75 x_Leaf,_greens,_mustard
#  - 1.1 x_Leaf,_mustard_spinach,_raw - 1.45 x_Leaf,_pumpkin,_raw
#  - 3.25 x_Mango,_ripe - 3.25 x_Mango,_unripe - 3.3 x_Milk,_cow,_fresh
#  - 14.8 x_Mushrooms,_shiitake,_dried - 1.7 x_Mushrooms,_shiitake,_raw
#  - 19.2 x_Noodles,_egg,_dry,_enriched - 5.4 x_Noodles,_rice,_cooked
#  - 43.1 x_Oil,_vegetable - 2.95 x_Onion,_raw - 2.2 x_Orange
#  - 1.65 x_Papaya,_ripe - 1.1 x_Papaya,_unripe,_raw
#  - 28.35 x_Peanut,_without_shell - 2.35 x_Pineapple,_ripe
#  - 5.8 x_Plantain,_all_varieties - 11.2 x_Pork,_back_ribs,_raw
#  - 6.7 x_Pork,_liver,_raw - 10.55 x_Pork,_meat,_raw
#  - 5.8 x_Pork_or_Goat,_blood,_coagulated - 0.9 x_Pumpkin,_raw
#  - 10.4 x_Quail,_meat - 0.65 x_Radish,_chinese,_raw
#  - 17.65 x_Rice,_white,_polished,_raw - 3.95 x_Shrimp,_raw
#  - 21.2 x_Soybean,_dried,_raw - 7.35 x_Squid,_raw + 350.55 x_Sugar,_palm
#  + 378.1 x_Sugar,_white
#  - 5.2 x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  - 4.9 x_Sweet_potato,_white_flesh,_raw - 4.6 x_Taro,_tuber,_raw - 3.8 x_Tofu
#  - 0.8 x_Tomato,_red,_ripe,_raw - 2.15 x_Water_spinach,_raw
#  - 1.9 x_Yam_bean,_jicama,_raw - 3.05 x_Yogurt <= 0
#
# offal_Beef,_blood,_coagulated_limit: x_Beef,_blood,_coagulated
#  <= 10.0858369099
#
# offal_Beef,_liver,_raw_limit: x_Beef,_liver,_raw <= 10.0858369099
#
# offal_Chicken,_liver,_raw_limit: x_Chicken,_liver,_raw <= 10.0858369099
#
# offal_Duck,_liver,_raw_limit: x_Duck,_liver,_raw <= 10.0858369099
#
# offal_Pork,_liver,_raw_limit: x_Pork,_liver,_raw <= 10.0858369099
#
# offal_Pork_or_Goat,_blood,_coagulated_limit: x_Pork_or_Goat,_blood,_coagulated
#  <= 10.0858369099
#
# food_group_Starchy_staples_lower_limit: x_Cassava,_white
#  + x_Noodles,_egg,_dry,_enriched + x_Noodles,_rice,_cooked
#  + x_Plantain,_all_varieties + x_Rice,_white,_polished,_raw
#  + x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + x_Sweet_potato,_white_flesh,_raw + x_Taro,_tuber,_raw
#  + x_Yam_bean,_jicama,_raw >= 0
#
# food_group_Vegetables_lower_limit: x_Banana_flower_heart
#  + x_Bean,_yard_long_bean,_immature,_raw + x_Cabbage,_chinese,_pak_choi,_raw
#  + x_Cabbage,_chinese,_pe_tsai,_raw + x_Cabbage,_chinese,_raw + x_Carrot,_raw
#  + x_Cauliflower,_raw + x_Cucumber,_raw + x_Eggplant,_purple + x_Eggplant,_raw
#  + x_Gourd,_bitter,_raw + x_Gourd,_ridge,_raw + x_Gourd,_sponge,_raw
#  + x_Gourd,_wax + x_Ivygourd,_leaf,_raw + x_Kale,_raw
#  + x_Leaf,_amaranth,_spiney,_raw + x_Leaf,_bitter_gourd,_raw
#  + x_Leaf,_drumstick,_raw + x_Leaf,_greens,_mustard
#  + x_Leaf,_mustard_spinach,_raw + x_Leaf,_pumpkin,_raw
#  + x_Mushrooms,_shiitake,_dried + x_Mushrooms,_shiitake,_raw + x_Onion,_raw
#  + x_Pumpkin,_raw + x_Radish,_chinese,_raw + x_Tomato,_red,_ripe,_raw
#  + x_Water_spinach,_raw >= 201.716738197
#
# food_group_Fruits_lower_limit: x_Banana,_ripe + x_Guava + x_Jackfruit,_ripe
#  + x_Mango,_ripe + x_Mango,_unripe + x_Orange + x_Papaya,_ripe
#  + x_Papaya,_unripe,_raw + x_Pineapple,_ripe >= 201.716738197
#
# food_group_Animal_source_foods_lower_limit: x_Beef,_blood,_coagulated
#  + x_Beef,_liver,_raw + x_Beef,_meat,_lean,_boneless,_raw
#  + x_Chicken,_liver,_raw + x_Chicken,_meat + x_Duck,_liver,_raw
#  + x_Duck,_meat,_raw + x_Egg,_chicken,_farmed,_raw + x_Egg,_duck,_whole,_raw
#  + x_Fish,_Snakehead,_dried
#  + x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw + x_Fish,_catfish,_raw
#  + x_Fish,_days_mystus,_eyes_included,_raw
#  + x_Fish,_gouramy,_eyes_included,_raw + x_Fish,_small,_fresh,_fresh_water
#  + x_Fish,_snakehead,_striped,_raw + x_Fish,_tilapia,_dried
#  + x_Fish,_tilapia,_raw + x_Fish_paste,_red,_fermented + x_Milk,_cow,_fresh
#  + x_Pork,_back_ribs,_raw + x_Pork,_liver,_raw + x_Pork,_meat,_raw
#  + x_Pork_or_Goat,_blood,_coagulated + x_Quail,_meat + x_Shrimp,_raw
#  + x_Squid,_raw + x_Yogurt >= 0
#
# food_group_Legumes,_nuts_&_seeds_lower_limit: x_Bean,_kidney,_dried,_raw
#  + x_Bean,_mung,_dry + x_Beansprout,_mung_bean,_raw + x_Peanut,_without_shell
#  + x_Soybean,_dried,_raw + x_Tofu >= 0
#
# food_group_Oils_&_fats_lower_limit: x_Butter,_CotD + x_Oil,_vegetable >= 0
#
# food_group_Sugars_lower_limit: x_Sugar,_palm + x_Sugar,_white >= 0
#
# food_subgroup_Fish_(dried)_lower_limit: x_Fish,_Snakehead,_dried
#  + x_Fish,_tilapia,_dried >= 0
#
# food_subgroup_Processed_fish_and_shellfish_lower_limit:
#  x_Fish_paste,_red,_fermented + x_Shrimp,_raw + x_Squid,_raw >= 0
#
# food_subgroup_Roots,_tubers_and_plantains_(general)_lower_limit:
#  x_Cassava,_white + x_Plantain,_all_varieties
#  + x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw
#  + x_Sweet_potato,_white_flesh,_raw + x_Taro,_tuber,_raw
#  + x_Yam_bean,_jicama,_raw >= 0
#
# food_subgroup_Rice_lower_limit: x_Noodles,_rice,_cooked
#  + x_Rice,_white,_polished,_raw >= 0
#
# food_subgroup_Fats_and_oils_(general)_lower_limit: x_Butter,_CotD
#  + x_Oil,_vegetable >= 0
#
# food_subgroup_Milk_and_milk_products_(general)_lower_limit: x_Milk,_cow,_fresh
#  + x_Yogurt >= 0
#
# food_subgroup_Pulses,_seeds_and_nuts_(general)_lower_limit:
#  x_Bean,_kidney,_dried,_raw + x_Bean,_mung,_dry + x_Beansprout,_mung_bean,_raw
#  + x_Peanut,_without_shell + x_Soybean,_dried,_raw + x_Tofu >= 0
#
# food_subgroup_Yellow_and_orange_fruits_lower_limit: x_Mango,_ripe
#  + x_Mango,_unripe + x_Papaya,_ripe + x_Papaya,_unripe,_raw >= 0
#
# food_subgroup_Other_vegetables_lower_limit: x_Banana_flower_heart
#  + x_Bean,_yard_long_bean,_immature,_raw + x_Carrot,_raw + x_Cauliflower,_raw
#  + x_Cucumber,_raw + x_Eggplant,_purple + x_Eggplant,_raw
#  + x_Gourd,_bitter,_raw + x_Gourd,_ridge,_raw + x_Gourd,_sponge,_raw
#  + x_Gourd,_wax + x_Mushrooms,_shiitake,_dried + x_Mushrooms,_shiitake,_raw
#  + x_Onion,_raw + x_Pumpkin,_raw + x_Radish,_chinese,_raw
#  + x_Tomato,_red,_ripe,_raw >= 0
#
# food_subgroup_Other_and_mixed_cereals_lower_limit:
#  x_Noodles,_egg,_dry,_enriched >= 0
#
# food_subgroup_Poultry_lower_limit: x_Chicken,_liver,_raw + x_Chicken,_meat
#  + x_Duck,_liver,_raw + x_Duck,_meat,_raw + x_Quail,_meat >= 0
#
# food_subgroup_Fruits_(other)_lower_limit: x_Banana,_ripe + x_Guava
#  + x_Jackfruit,_ripe + x_Orange + x_Pineapple,_ripe >= 0
#
# food_subgroup_Eggs_lower_limit: x_Egg,_chicken,_farmed,_raw
#  + x_Egg,_duck,_whole,_raw >= 0
#
# food_subgroup_Red_meat/mammals,_reptiles_and_amphibians_lower_limit:
#  x_Beef,_blood,_coagulated + x_Beef,_liver,_raw
#  + x_Beef,_meat,_lean,_boneless,_raw + x_Pork,_back_ribs,_raw
#  + x_Pork,_liver,_raw + x_Pork,_meat,_raw + x_Pork_or_Goat,_blood,_coagulated
#  >= 0
#
# food_subgroup_Sugars_lower_limit: x_Sugar,_palm + x_Sugar,_white >= 0
#
# food_subgroup_Freshwater_fish_lower_limit:
#  x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw + x_Fish,_catfish,_raw
#  + x_Fish,_days_mystus,_eyes_included,_raw
#  + x_Fish,_gouramy,_eyes_included,_raw + x_Fish,_small,_fresh,_fresh_water
#  + x_Fish,_snakehead,_striped,_raw + x_Fish,_tilapia,_raw >= 0
#
# food_subgroup_Leafy_vegetables_lower_limit: x_Cabbage,_chinese,_pak_choi,_raw
#  + x_Cabbage,_chinese,_pe_tsai,_raw + x_Cabbage,_chinese,_raw
#  + x_Ivygourd,_leaf,_raw + x_Kale,_raw + x_Leaf,_amaranth,_spiney,_raw
#  + x_Leaf,_bitter_gourd,_raw + x_Leaf,_drumstick,_raw
#  + x_Leaf,_greens,_mustard + x_Leaf,_mustard_spinach,_raw
#  + x_Leaf,_pumpkin,_raw + x_Water_spinach,_raw >= 0
#
# VARIABLES
# CO2e_(Kg.day) free Continuous
# Cost_(KHR.day) free Continuous
# Dietary_shift_index_(unitless) free Continuous
# x_Banana,_ripe Continuous
# x_Banana_flower_heart Continuous
# x_Bean,_kidney,_dried,_raw Continuous
# x_Bean,_mung,_dry Continuous
# x_Bean,_yard_long_bean,_immature,_raw Continuous
# x_Beansprout,_mung_bean,_raw Continuous
# x_Beef,_blood,_coagulated Continuous
# x_Beef,_liver,_raw Continuous
# x_Beef,_meat,_lean,_boneless,_raw Continuous
# x_Butter,_CotD Continuous
# x_Cabbage,_chinese,_pak_choi,_raw Continuous
# x_Cabbage,_chinese,_pe_tsai,_raw Continuous
# x_Cabbage,_chinese,_raw Continuous
# x_Carrot,_raw Continuous
# x_Cassava,_white Continuous
# x_Cauliflower,_raw Continuous
# x_Chicken,_liver,_raw Continuous
# x_Chicken,_meat Continuous
# x_Cucumber,_raw Continuous
# x_Duck,_liver,_raw Continuous
# x_Duck,_meat,_raw Continuous
# x_Egg,_chicken,_farmed,_raw Continuous
# x_Egg,_duck,_whole,_raw Continuous
# x_Eggplant,_purple Continuous
# x_Eggplant,_raw Continuous
# x_Fish,_Snakehead,_dried Continuous
# x_Fish,_barb,_pool,_with_bones,_eyes_included,_raw Continuous
# x_Fish,_catfish,_raw Continuous
# x_Fish,_days_mystus,_eyes_included,_raw Continuous
# x_Fish,_gouramy,_eyes_included,_raw Continuous
# x_Fish,_small,_fresh,_fresh_water Continuous
# x_Fish,_snakehead,_striped,_raw Continuous
# x_Fish,_tilapia,_dried Continuous
# x_Fish,_tilapia,_raw Continuous
# x_Fish_paste,_red,_fermented Continuous
# x_Gourd,_bitter,_raw Continuous
# x_Gourd,_ridge,_raw Continuous
# x_Gourd,_sponge,_raw Continuous
# x_Gourd,_wax Continuous
# x_Guava Continuous
# x_Ivygourd,_leaf,_raw Continuous
# x_Jackfruit,_ripe Continuous
# x_Kale,_raw Continuous
# x_Leaf,_amaranth,_spiney,_raw Continuous
# x_Leaf,_bitter_gourd,_raw Continuous
# x_Leaf,_drumstick,_raw Continuous
# x_Leaf,_greens,_mustard Continuous
# x_Leaf,_mustard_spinach,_raw Continuous
# x_Leaf,_pumpkin,_raw Continuous
# x_Mango,_ripe Continuous
# x_Mango,_unripe Continuous
# x_Milk,_cow,_fresh Continuous
# x_Mushrooms,_shiitake,_dried Continuous
# x_Mushrooms,_shiitake,_raw Continuous
# x_Noodles,_egg,_dry,_enriched Continuous
# x_Noodles,_rice,_cooked Continuous
# x_Oil,_vegetable Continuous
# x_Onion,_raw Continuous
# x_Orange Continuous
# x_Papaya,_ripe Continuous
# x_Papaya,_unripe,_raw Continuous
# x_Peanut,_without_shell Continuous
# x_Pineapple,_ripe Continuous
# x_Plantain,_all_varieties Continuous
# x_Pork,_back_ribs,_raw Continuous
# x_Pork,_liver,_raw Continuous
# x_Pork,_meat,_raw Continuous
# x_Pork_or_Goat,_blood,_coagulated Continuous
# x_Pumpkin,_raw Continuous
# x_Quail,_meat Continuous
# x_Radish,_chinese,_raw Continuous
# x_Rice,_white,_polished,_raw Continuous
# x_Shrimp,_raw Continuous
# x_Soybean,_dried,_raw Continuous
# x_Squid,_raw Continuous
# x_Sugar,_palm Continuous
# x_Sugar,_white Continuous
# x_Sweet_potato,_purple_skin,_pale_yellow_flesh,_raw Continuous
# x_Sweet_potato,_white_flesh,_raw Continuous
# x_Taro,_tuber,_raw Continuous
# x_Tofu Continuous
# x_Tomato,_red,_ripe,_raw Continuous
# x_Water_spinach,_raw Continuous
# x_Yam_bean,_jicama,_raw Continuous
# x_Yogurt Continuous
# 0 <= y_Eggs <= 1 Integer
# 0 <= y_Fats_and_oils_(general) <= 1 Integer
# 0 <= y_Fish_(dried) <= 1 Integer
# 0 <= y_Freshwater_fish <= 1 Integer
# 0 <= y_Fruits_(other) <= 1 Integer
# 0 <= y_Leafy_vegetables <= 1 Integer
# 0 <= y_Milk_and_milk_products_(general) <= 1 Integer
# 0 <= y_Other_and_mixed_cereals <= 1 Integer
# 0 <= y_Other_vegetables <= 1 Integer
# 0 <= y_Poultry <= 1 Integer
# 0 <= y_Processed_fish_and_shellfish <= 1 Integer
# 0 <= y_Pulses,_seeds_and_nuts_(general) <= 1 Integer
# 0 <= y_Red_meat_mammals,_reptiles_and_amphibians <= 1 Integer
# 0 <= y_Rice <= 1 Integer
# 0 <= y_Roots,_tubers_and_plantains_(general) <= 1 Integer
# 0 <= y_Sugars <= 1 Integer
# 0 <= y_Yellow_and_orange_fruits <= 1 Integer
# z_lower_Fats_and_oils_(general) Continuous
# z_lower_Freshwater_fish Continuous
# z_lower_Leafy_vegetables Continuous
# z_lower_Other_vegetables Continuous
# z_lower_Rice Continuous
# z_lower_Sugars Continuous
# z_lower_Yellow_and_orange_fruits Continuous
# z_upper_Eggs Continuous
# z_upper_Fats_and_oils_(general) Continuous
# z_upper_Fish_(dried) Continuous
# z_upper_Freshwater_fish Continuous
# z_upper_Fruits_(other) Continuous
# z_upper_Leafy_vegetables Continuous
# z_upper_Milk_and_milk_products_(general) Continuous
# z_upper_Other_and_mixed_cereals Continuous
# z_upper_Other_vegetables Continuous
# z_upper_Poultry Continuous
# z_upper_Processed_fish_and_shellfish Continuous
# z_upper_Pulses,_seeds_and_nuts_(general) Continuous
# z_upper_Red_meat_mammals,_reptiles_and_amphibians Continuous
# z_upper_Rice Continuous
# z_upper_Roots,_tubers_and_plantains_(general) Continuous
# z_upper_Sugars Continuous
# z_upper_Yellow_and_orange_fruits Continuous
